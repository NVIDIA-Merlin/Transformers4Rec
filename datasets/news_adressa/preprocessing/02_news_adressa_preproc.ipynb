# %%
import os
import numpy as np
import pandas as pd
from collections import Counter
from gauss_rank import GaussRankScaler
import json
import pytz
import datetime
from sklearn.model_selection import train_test_split

# %%
INPUT_CLICKS_PATH = '/home/gmoreira/dataset/adressa/preprocessed/sessions_processed_by_spark/'
INPUT_ARTICLES_PATH = '/home/gmoreira/dataset/adressa/preprocessed/adressa_articles.csv'

# %%
OUTPUT_PATH = '/home/gmoreira/dataset/adressa/preprocessed/sessions_by_hour_parquet/'
# !mkdir -p $OUTPUT_PATH

# %%
def load_sessions_json_file(json_path):
    with open(json_path, 'r') as fi:
        for line in fi:
            yield json.loads(line)

def load_sessions_hour(session_hour_path):
    sessions = []
    for session_file in os.listdir(session_hour_path):
        session_file_path = os.path.join(session_hour_path, session_file)
        sessions_hour = load_sessions_json_file(session_file_path)
        for session in sessions_hour:
            sessions.append(session)        
    return sessions

def load_sessions_hours(folder_path):
    #Sorting hours directories (treating cases where number of digits is lower. E.x. "session_hour=3" < "session_hour=20")
    hour_folders = sorted([path for path in os.listdir(folder_path) \
                             if os.path.isdir(os.path.join(folder_path,path))], 
                          key=lambda x: "{:0>5}".format(x.split('=')[1]))
    
    for hour_folder in hour_folders:
        hour_index = int(hour_folder.split('=')[1])
        hour_folder_path = os.path.join(folder_path, hour_folder)
        sessions_hour = load_sessions_hour(hour_folder_path)
        yield (hour_index, sessions_hour)

# %%
def gini_index(array):
    """Calculate the Gini coefficient of a numpy array."""
    # based on bottom eq:
    # http://www.statsdirect.com/help/generatedimages/equations/equation154.svg
    # from:
    # http://www.statsdirect.com/help/default.htm#nonparametric_methods/gini.htm
    # All values are treated equally, arrays must be 1d:
    array = array.flatten()
    if np.amin(array) < 0:
        # Values cannot be negative:
        array -= np.amin(array)
    # Values cannot be 0:
    array += 0.0000001
    # Values must be sorted:
    array = np.sort(array)
    # Index per array element:
    index = np.arange(1,array.shape[0]+1)
    # Number of array elements:
    n = array.shape[0]
    # Gini coefficient:
    return ((np.sum((2 * index - n  - 1) * array)) / (n * np.sum(array)))

# %%
numeric_scalers = {
    '_elapsed_ms_since_last_click': {
                 #Set Maximum of 60 min, just to separate returning users, whose elapsed time since last click will be greater than the max 30-min limit for sessions
                 'valid_max': 60 * 60 * 1000.0, 
                 'avg':    789935.7,
                 'stddev': 1371436.0},
    'active_time_secs': {
                 'valid_max': 900.0,
                 'avg':    65.0,
                 'stddev': 69.37},
    'active_time_secs_by_word': {
                 'valid_max': 10.0,
                 'avg':    1.854,
                 'stddev': 1.474}
}

def standardize_num_feature(feature, values):
    scaler_config = numeric_scalers[feature]
    normalizer = lambda x: (min(int(x), scaler_config['valid_max']) - scaler_config['avg']) / scaler_config['stddev']    
    return  list([normalizer(value) for value in values])

def get_cicled_feature_value(value, max_value):
    value_scaled = (value + 0.000001) / max_value
    value_sin = np.sin(2*np.pi*value_scaled)
    value_cos = np.cos(2*np.pi*value_scaled)
    return value_sin, value_cos

def extract_local_hour_weekday(timestamp_in_utc, local_tz):
    dt = pytz.utc.localize(datetime.datetime.utcfromtimestamp(timestamp_in_utc)).astimezone(pytz.timezone(local_tz))
    return dt.hour + (dt.minute/60.0), dt.weekday() #First day is Monday


def get_time_features(timestamp, default_timezone='Europe/Oslo'):
    #Converting timestamp to the fDefault timezone, where most clicks originate
    local_hour, local_weekday = extract_local_hour_weekday(int(timestamp)//1000, default_timezone)        
    #Converting hour in two cycling features to represent the continuity of the hours
    local_hour_sin, local_hour_cos = get_cicled_feature_value(local_hour, 24)
    local_weekday_sin, local_weekday_cos = get_cicled_feature_value(local_weekday+1, 7)
    return local_hour_sin, local_hour_cos, local_weekday_sin, local_weekday_cos


article_first_time_seen = dict()

def process_session_clicks_features(sessions_hour, articles_df):
    global article_first_time_seen
    sessions = []

    session_count = 0
    clicked_articles_ids = []
    unique_clicked_articles = set()
    #Normalizing numerical features (standardization) and creating time features
    for session in sessions_hour:
        session_count += 1
        for click in session['clicks']:
            
            click['category0_encoded'], click['category1_encoded'], click['author_encoded'] = \
                    articles_df.loc[click['article_id']][['category0_encoded', 'category1_encoded', 'author_encoded']]
            
            if click['article_id'] not in article_first_time_seen:
                article_first_time_seen[click['article_id']] = click['timestamp']
                
            click['item_age_hours'] = (click['timestamp'] - article_first_time_seen[click['article_id']]) / (1000*60*60)
            
            click['hour_sin'], click['hour_cos'], click['weekday_sin'], click['weekday_cos'] = \
                    get_time_features(click['timestamp']//1000)
                
            #Applying standardization on elapsed time
            click['_elapsed_ms_since_last_click'] = standardize_num_feature('_elapsed_ms_since_last_click', [click['_elapsed_ms_since_last_click']])[0]

            #Copying click attributes as lists in the session
            for key in click:
                if key != "user_id":
                    if key not in session:
                        session[key] = [click[key]]
                    else:
                        session[key].append(click[key])

            clicked_articles_ids.append(click['article_id'])
            unique_clicked_articles.add(click['article_id'])

        #Removing clicks property, as its values were copied to individual list columns
        del session['clicks']
        sessions.append(session)

    #Ensuring sessions within the hour are sorted by session id (time)
    sessions_df = pd.DataFrame(sessions).sort_values('session_id')
    
    # Normalize the item_age_hours with GaussRank (considering only the distribution of the current hour)
    scaler = GaussRankScaler()
    item_age_hours_exploded = sessions_df.explode('item_age_hours')[['item_age_hours']]
    clicks_item_age_hours_mean = item_age_hours_exploded['item_age_hours'].mean()
    clicks_item_age_hours_median = item_age_hours_exploded['item_age_hours'].median()
    
    scaler.fit(item_age_hours_exploded)
    
    sessions_df['item_age_hours_norm'] = sessions_df['item_age_hours'].apply(lambda x: np.squeeze(scaler.transform(np.expand_dims(np.array(x), -1))))
    
    #Printing stats
    clicks_by_articles_counter = dict(Counter(clicked_articles_ids))
    clicks_by_articles = np.array(list(clicks_by_articles_counter.values()))
    total_clicks = np.sum(clicks_by_articles)
    clicks_by_articles_norm = clicks_by_articles / total_clicks
    clicks_by_articles_norm_mean = np.mean(clicks_by_articles_norm)
    clicks_by_articles_norm_median = np.median(clicks_by_articles_norm)
    

    stats = {'session_count': session_count,
             'clicks': total_clicks,
             'clicks_by_session': total_clicks / session_count,
             'unique_articles': len(unique_clicked_articles),
             'clicks_by_article':float(total_clicks)/len(unique_clicked_articles),
             'norm_pop_mean': clicks_by_articles_norm_mean,
             'norm_pop_median': clicks_by_articles_norm_median,
             'gini_index': gini_index(clicks_by_articles.astype(np.float32)),
             'clicks_item_age_hours_mean': clicks_item_age_hours_mean,
             'clicks_item_age_hours_median': clicks_item_age_hours_median,
             'clicks_item_age_hours_after_norm_mean': sessions_df.explode('item_age_hours_norm')['item_age_hours_norm'].mean(),
             'clicks_item_age_hours_after_norm_median': sessions_df.explode('item_age_hours_norm')['item_age_hours_norm'].median()
    }

    print("Stats :{}".format(stats))
    
    return sessions_df, stats, clicks_by_articles_counter

# %%
articles_df = pd.read_csv(INPUT_ARTICLES_PATH)
articles_df = articles_df[['id_encoded', 'category0_encoded', 'category1_encoded', 'author_encoded']].set_index('id_encoded')
articles_df
# Out:
#             category0_encoded  category1_encoded  author_encoded
# id_encoded
# 1                           1                  1               1
# 2                           2                  2              65
# 3                           3                  3               7
# 4                           3                  4              64
# 5                           2                  5             106
# ...                       ...                ...             ...
# 72928                       3                  8              47
# 72929                      11                 24               1
# 72930                       2                 13              17
# 72931                       2                  2              41
# 72932                       6                 58               3
#
# [72932 rows x 3 columns]

# %%
articles_df.agg(['min', 'max'])
# Out:
#      category0_encoded  category1_encoded  author_encoded
# min                  1                  1               1
# max                 40                127             111

# %%
counter = 1

for (hour_index, sessions_hour_df) in load_sessions_hours(INPUT_CLICKS_PATH):  
    hour_index += 1
    print('Processing hour {}'.format(hour_index))
    
    sessions_df, hour_stats, hour_clicks_by_articles_counter = \
            process_session_clicks_features(sessions_hour_df, articles_df)
        
    if len(sessions_df) < 100:
        print("Ignoring this hour file, because has only {} sessions".format(len(sessions_df)))
        continue
    
    print(f"{hour_index}->{counter}", "# sessions: {}".format(len(sessions_df)))
    
    hour_files_path = os.path.join(OUTPUT_PATH, f"{counter:04}")
    os.makedirs(hour_files_path, exist_ok=True)
    
    #As the number of sessions by hour is small, uses all available sessions for training, 
    #and splits the same data as valid and test, as the evaluation is always performed in the next hour
    train_df = sessions_df
    sessions_df.to_parquet(os.path.join(hour_files_path, "train.parquet"))    
    valid_df, test_df = train_test_split(train_df, test_size=0.5, shuffle=True)
    valid_df.sort_values(['session_start']).to_parquet(os.path.join(hour_files_path, "valid.parquet"))    
    test_df.sort_values(['session_start']).to_parquet(os.path.join(hour_files_path, "test.parquet")) 
    
    counter += 1
    print()
# Out:
# Processing hour 1
# Stats :{'session_count': 2239, 'clicks': 5297, 'clicks_by_session': 2.3657882983474767, 'unique_articles': 162, 'clicks_by_article': 32.69753086419753, 'norm_pop_mean': 0.006172839506172839, 'norm_pop_median': 0.00018878610534264677, 'gini_index': 0.8954416303904238, 'clicks_item_age_hours_mean': 0.4808019214230275, 'clicks_item_age_hours_median': 0.4872222222222222, 'clicks_item_age_hours_after_norm_mean': -0.0147975134408703, 'clicks_item_age_hours_after_norm_median': -0.009636918750654422}
# 1->1 # sessions: 2239
#
# Processing hour 2
# Stats :{'session_count': 1665, 'clicks': 3940, 'clicks_by_session': 2.3663663663663663, 'unique_articles': 128, 'clicks_by_article': 30.78125, 'norm_pop_mean': 0.0078125, 'norm_pop_median': 0.0005076142131979696, 'gini_index': 0.8778196373576214, 'clicks_item_age_hours_mean': 1.221225606316979, 'clicks_item_age_hours_median': 1.2709722222222224, 'clicks_item_age_hours_after_norm_mean': -0.006276648308866803, 'clicks_item_age_hours_after_norm_median': -0.01870312966211074}
# 2->2 # sessions: 1665
#
# Processing hour 3
# Stats :{'session_count': 1033, 'clicks': 2471, 'clicks_by_session': 2.392061955469506, 'unique_articles': 93, 'clicks_by_article': 26.56989247311828, 'norm_pop_mean': 0.010752688172043008, 'norm_pop_median': 0.0008093889113719142, 'gini_index': 0.8446538981033572, 'clicks_item_age_hours_mean': 2.134787647825892, 'clicks_item_age_hours_median': 2.254722222222222, 'clicks_item_age_hours_after_norm_mean': 0.008449512722262877, 'clicks_item_age_hours_after_norm_median': 0.021388464821860777}
# 3->3 # sessions: 1033
#
# Processing hour 4
# Stats :{'session_count': 441, 'clicks': 1066, 'clicks_by_session': 2.417233560090703, 'unique_articles': 90, 'clicks_by_article': 11.844444444444445, 'norm_pop_mean': 0.011111111111111113, 'norm_pop_median': 0.0009380863039399625, 'gini_index': 0.8103397933994951, 'clicks_item_age_hours_mean': 3.1043839899937495, 'clicks_item_age_hours_median': 3.2581944444444444, 'clicks_item_age_hours_after_norm_mean': -0.04629799964569371, 'clicks_item_age_hours_after_norm_median': -0.005438319801145923}
# 4->4 # sessions: 441
#
# Processing hour 5
# Stats :{'session_count': 250, 'clicks': 630, 'clicks_by_session': 2.52, 'unique_articles': 64, 'clicks_by_article': 9.84375, 'norm_pop_mean': 0.015624999999999998, 'norm_pop_median': 0.0031746031746031746, 'gini_index': 0.7282242033689741, 'clicks_item_age_hours_mean': 3.5140264550264515, 'clicks_item_age_hours_median': 4.146527777777778, 'clicks_item_age_hours_after_norm_mean': -0.021311785728614162, 'clicks_item_age_hours_after_norm_median': -0.005903895278524685}
# 5->5 # sessions: 250
#
# Processing hour 6
# Stats :{'session_count': 215, 'clicks': 528, 'clicks_by_session': 2.4558139534883723, 'unique_articles': 46, 'clicks_by_article': 11.478260869565217, 'norm_pop_mean': 0.021739130434782615, 'norm_pop_median': 0.003787878787878788, 'gini_index': 0.709568508681062, 'clicks_item_age_hours_mean': 3.818900462962965, 'clicks_item_age_hours_median': 5.012777777777778, 'clicks_item_age_hours_after_norm_mean': -0.008760275615999145, 'clicks_item_age_hours_after_norm_median': 0.003659857548561513}
# 6->6 # sessions: 215
#
# Processing hour 7
# Stats :{'session_count': 350, 'clicks': 884, 'clicks_by_session': 2.525714285714286, 'unique_articles': 62, 'clicks_by_article': 14.258064516129032, 'norm_pop_mean': 0.016129032258064512, 'norm_pop_median': 0.0022624434389140274, 'gini_index': 0.7670048147270304, 'clicks_item_age_hours_mean': 4.308104260935145, 'clicks_item_age_hours_median': 5.660555555555556, 'clicks_item_age_hours_after_norm_mean': -0.008523540086750157, 'clicks_item_age_hours_after_norm_median': 0.010716505831443918}
# 7->7 # sessions: 350
#
# Processing hour 8
# Stats :{'session_count': 607, 'clicks': 1566, 'clicks_by_session': 2.5799011532125204, 'unique_articles': 81, 'clicks_by_article': 19.333333333333332, 'norm_pop_mean': 0.012345679012345682, 'norm_pop_median': 0.001277139208173691, 'gini_index': 0.8127650836914627, 'clicks_item_age_hours_mean': 5.292347275436361, 'clicks_item_age_hours_median': 6.794722222222222, 'clicks_item_age_hours_after_norm_mean': -0.0014299313826258, 'clicks_item_age_hours_after_norm_median': 0.020185757703610856}
# 8->8 # sessions: 607
#
# Processing hour 9
# Stats :{'session_count': 1221, 'clicks': 3149, 'clicks_by_session': 2.579033579033579, 'unique_articles': 119, 'clicks_by_article': 26.462184873949578, 'norm_pop_mean': 0.008403361344537813, 'norm_pop_median': 0.0006351222610352493, 'gini_index': 0.8558032284254896, 'clicks_item_age_hours_mean': 6.831842560248395, 'clicks_item_age_hours_median': 8.161666666666667, 'clicks_item_age_hours_after_norm_mean': 0.025151189274097728, 'clicks_item_age_hours_after_norm_median': 0.05858480243674326}
# 9->9 # sessions: 1221
#
# Processing hour 10
# Stats :{'session_count': 2459, 'clicks': 6374, 'clicks_by_session': 2.5921106140707604, 'unique_articles': 165, 'clicks_by_article': 38.63030303030303, 'norm_pop_mean': 0.00606060606060606, 'norm_pop_median': 0.00031377470975839345, 'gini_index': 0.8840497848396378, 'clicks_item_age_hours_mean': 7.694815265139661, 'clicks_item_age_hours_median': 9.111805555555556, 'clicks_item_age_hours_after_norm_mean': 0.05316119369185381, 'clicks_item_age_hours_after_norm_median': 0.10760230023797533}
# 10->10 # sessions: 2459
#
# Processing hour 11
# Stats :{'session_count': 3100, 'clicks': 8087, 'clicks_by_session': 2.608709677419355, 'unique_articles': 172, 'clicks_by_article': 47.01744186046512, 'norm_pop_mean': 0.005813953488372092, 'norm_pop_median': 0.00024731049833065413, 'gini_index': 0.8908922151329934, 'clicks_item_age_hours_mean': 8.48993315746809, 'clicks_item_age_hours_median': 10.059444444444445, 'clicks_item_age_hours_after_norm_mean': 0.06256749068607842, 'clicks_item_age_hours_after_norm_median': 0.13379541463596567}
# 11->11 # sessions: 3100
#
# Processing hour 12
# Stats :{'session_count': 2558, 'clicks': 6546, 'clicks_by_session': 2.559030492572322, 'unique_articles': 186, 'clicks_by_article': 35.193548387096776, 'norm_pop_mean': 0.005376344086021506, 'norm_pop_median': 0.00030553009471432935, 'gini_index': 0.8749560586832351, 'clicks_item_age_hours_mean': 8.819899684285561, 'clicks_item_age_hours_median': 11.024027777777778, 'clicks_item_age_hours_after_norm_mean': 0.05749067186880855, 'clicks_item_age_hours_after_norm_median': 0.12594367397066053}
# 12->12 # sessions: 2558
#
# Processing hour 13
# Stats :{'session_count': 2142, 'clicks': 5539, 'clicks_by_session': 2.585901027077498, 'unique_articles': 199, 'clicks_by_article': 27.834170854271356, 'norm_pop_mean': 0.0050251256281407045, 'norm_pop_median': 0.0003610760064993681, 'gini_index': 0.8647480032607633, 'clicks_item_age_hours_mean': 8.479564251469386, 'clicks_item_age_hours_median': 11.748611111111112, 'clicks_item_age_hours_after_norm_mean': 0.035129975145092404, 'clicks_item_age_hours_after_norm_median': 0.07973513729539608}
# 13->13 # sessions: 2142
#
# Processing hour 14
# Stats :{'session_count': 1501, 'clicks': 3839, 'clicks_by_session': 2.557628247834777, 'unique_articles': 168, 'clicks_by_article': 22.851190476190474, 'norm_pop_mean': 0.005952380952380954, 'norm_pop_median': 0.0005209690023443605, 'gini_index': 0.834224871256293, 'clicks_item_age_hours_mean': 9.057684943995836, 'clicks_item_age_hours_median': 12.380833333333333, 'clicks_item_age_hours_after_norm_mean': 0.013190007522581391, 'clicks_item_age_hours_after_norm_median': 0.0471112939970871}
# 14->14 # sessions: 1501
#
# Processing hour 15
# Stats :{'session_count': 1262, 'clicks': 3062, 'clicks_by_session': 2.426307448494453, 'unique_articles': 210, 'clicks_by_article': 14.58095238095238, 'norm_pop_mean': 0.004761904761904763, 'norm_pop_median': 0.00032658393207054214, 'gini_index': 0.8513607644555743, 'clicks_item_age_hours_mean': 10.21962460991362, 'clicks_item_age_hours_median': 13.904722222222222, 'clicks_item_age_hours_after_norm_mean': -0.03176810988270031, 'clicks_item_age_hours_after_norm_median': 0.04305198258297219}
# 15->15 # sessions: 1262
#
# Processing hour 16
# Stats :{'session_count': 1559, 'clicks': 3835, 'clicks_by_session': 2.4599101988454137, 'unique_articles': 214, 'clicks_by_article': 17.92056074766355, 'norm_pop_mean': 0.004672897196261682, 'norm_pop_median': 0.0002607561929595828, 'gini_index': 0.863094467708681, 'clicks_item_age_hours_mean': 8.050421483413022, 'clicks_item_age_hours_median': 10.461944444444445, 'clicks_item_age_hours_after_norm_mean': -0.02333424473862267, 'clicks_item_age_hours_after_norm_median': -0.009910328142776348}
# 16->16 # sessions: 1559
#
# Processing hour 17
# Stats :{'session_count': 6746, 'clicks': 17007, 'clicks_by_session': 2.521049510821227, 'unique_articles': 214, 'clicks_by_article': 79.47196261682242, 'norm_pop_mean': 0.004672897196261682, 'norm_pop_median': 5.8799317927912035e-05, 'gini_index': 0.9484865766202497, 'clicks_item_age_hours_mean': 3.1350117108641755, 'clicks_item_age_hours_median': 0.5738888888888889, 'clicks_item_age_hours_after_norm_mean': -0.253820953524194, 'clicks_item_age_hours_after_norm_median': -0.34314195228376315}
# 17->17 # sessions: 6746
#
# Processing hour 18
# Stats :{'session_count': 5355, 'clicks': 13579, 'clicks_by_session': 2.5357609710550886, 'unique_articles': 230, 'clicks_by_article': 59.03913043478261, 'norm_pop_mean': 0.004347826086956521, 'norm_pop_median': 7.364312541424258e-05, 'gini_index': 0.9358302616977101, 'clicks_item_age_hours_mean': 4.23869230265686, 'clicks_item_age_hours_median': 1.46, 'clicks_item_age_hours_after_norm_mean': -0.11774791816647237, 'clicks_item_age_hours_after_norm_median': -0.16637083866741442}
# 18->18 # sessions: 5355
#
# Processing hour 19
# Stats :{'session_count': 4067, 'clicks': 10478, 'clicks_by_session': 2.576346201131055, 'unique_articles': 253, 'clicks_by_article': 41.41501976284585, 'norm_pop_mean': 0.003952569169960475, 'norm_pop_median': 9.54380606986066e-05, 'gini_index': 0.9209433347331344, 'clicks_item_age_hours_mean': 4.64883547008547, 'clicks_item_age_hours_median': 2.2512499999999998, 'clicks_item_age_hours_after_norm_mean': -0.053103442012251326, 'clicks_item_age_hours_after_norm_median': -0.05735797607662588}
# 19->19 # sessions: 4067
#
# Processing hour 20
# Stats :{'session_count': 3491, 'clicks': 9000, 'clicks_by_session': 2.5780578630764825, 'unique_articles': 239, 'clicks_by_article': 37.65690376569037, 'norm_pop_mean': 0.0041841004184100415, 'norm_pop_median': 0.00011111111111111112, 'gini_index': 0.9059209662056812, 'clicks_item_age_hours_mean': 5.677170123456787, 'clicks_item_age_hours_median': 3.263472222222222, 'clicks_item_age_hours_after_norm_mean': -0.052232654540156, 'clicks_item_age_hours_after_norm_median': -0.034052161320055875}
# 20->20 # sessions: 3491
#
# Processing hour 21
# Stats :{'session_count': 3637, 'clicks': 9448, 'clicks_by_session': 2.5977453945559525, 'unique_articles': 306, 'clicks_by_article': 30.875816993464053, 'norm_pop_mean': 0.0032679738562091504, 'norm_pop_median': 0.00010584250635055038, 'gini_index': 0.9105886771314976, 'clicks_item_age_hours_mean': 5.141561088766583, 'clicks_item_age_hours_median': 2.678055555555556, 'clicks_item_age_hours_after_norm_mean': -0.06090025106422044, 'clicks_item_age_hours_after_norm_median': -0.060598532951873355}
# 21->21 # sessions: 3637
#
# Processing hour 22
# Stats :{'session_count': 4641, 'clicks': 12296, 'clicks_by_session': 2.6494290023701788, 'unique_articles': 281, 'clicks_by_article': 43.75800711743772, 'norm_pop_mean': 0.0035587188612099642, 'norm_pop_median': 8.132726089785297e-05, 'gini_index': 0.9152494685531716, 'clicks_item_age_hours_mean': 5.510749227391017, 'clicks_item_age_hours_median': 3.611527777777778, 'clicks_item_age_hours_after_norm_mean': -0.033230474441509825, 'clicks_item_age_hours_after_norm_median': -0.020648867135347478}
# 22->22 # sessions: 4641
#
# Processing hour 23
# Stats :{'session_count': 7816, 'clicks': 20735, 'clicks_by_session': 2.6528915046059365, 'unique_articles': 302, 'clicks_by_article': 68.65894039735099, 'norm_pop_mean': 0.0033112582781456954, 'norm_pop_median': 4.8227634434530984e-05, 'gini_index': 0.9397392509736896, 'clicks_item_age_hours_mean': 4.1288209013209265, 'clicks_item_age_hours_median': 1.458611111111111, 'clicks_item_age_hours_after_norm_mean': -0.268739303859823, 'clicks_item_age_hours_after_norm_median': -0.34555720924753197}
# 23->23 # sessions: 7816
#
# Processing hour 24
# Stats :{'session_count': 5393, 'clicks': 14570, 'clicks_by_session': 2.701650287409605, 'unique_articles': 283, 'clicks_by_article': 51.48409893992933, 'norm_pop_mean': 0.0035335689045936395, 'norm_pop_median': 6.863417982155113e-05, 'gini_index': 0.9228648822474825, 'clicks_item_age_hours_mean': 5.485439411271227, 'clicks_item_age_hours_median': 3.2993055555555557, 'clicks_item_age_hours_after_norm_mean': -0.17208783661005636, 'clicks_item_age_hours_after_norm_median': -0.17121766026248242}
# 24->24 # sessions: 5393
#
# Processing hour 25
# Stats :{'session_count': 2012, 'clicks': 5584, 'clicks_by_session': 2.775347912524851, 'unique_articles': 251, 'clicks_by_article': 22.247011952191237, 'norm_pop_mean': 0.00398406374501992, 'norm_pop_median': 0.00017908309455587392, 'gini_index': 0.8549783659994954, 'clicks_item_age_hours_mean': 7.399545079194525, 'clicks_item_age_hours_median': 5.358055555555556, 'clicks_item_age_hours_after_norm_mean': -0.03601179895137405, 'clicks_item_age_hours_after_norm_median': -0.03334753315197975}
# 25->25 # sessions: 2012
#
# Processing hour 26
# Stats :{'session_count': 918, 'clicks': 2607, 'clicks_by_session': 2.8398692810457518, 'unique_articles': 186, 'clicks_by_article': 14.016129032258064, 'norm_pop_mean': 0.005376344086021506, 'norm_pop_median': 0.0007671653241273494, 'gini_index': 0.7978168763477983, 'clicks_item_age_hours_mean': 8.533447236073824, 'clicks_item_age_hours_median': 6.329722222222222, 'clicks_item_age_hours_after_norm_mean': -0.04024506339044935, 'clicks_item_age_hours_after_norm_median': -0.02060427969118612}
# 26->26 # sessions: 918
#
# Processing hour 27
# Stats :{'session_count': 470, 'clicks': 1425, 'clicks_by_session': 3.0319148936170213, 'unique_articles': 176, 'clicks_by_article': 8.096590909090908, 'norm_pop_mean': 0.005681818181818182, 'norm_pop_median': 0.0007017543859649122, 'gini_index': 0.7535685768633178, 'clicks_item_age_hours_mean': 9.759473489278756, 'clicks_item_age_hours_median': 7.7588888888888885, 'clicks_item_age_hours_after_norm_mean': -0.04819028589047227, 'clicks_item_age_hours_after_norm_median': -0.019148826317638923}
# 27->27 # sessions: 470
#
# Processing hour 28
# Stats :{'session_count': 324, 'clicks': 919, 'clicks_by_session': 2.8364197530864197, 'unique_articles': 117, 'clicks_by_article': 7.854700854700854, 'norm_pop_mean': 0.008547008547008548, 'norm_pop_median': 0.002176278563656148, 'gini_index': 0.709969026101358, 'clicks_item_age_hours_mean': 10.448003264417848, 'clicks_item_age_hours_median': 8.658055555555556, 'clicks_item_age_hours_after_norm_mean': -0.028685334992693365, 'clicks_item_age_hours_after_norm_median': -0.010692128800424361}
# 28->28 # sessions: 324
#
# Processing hour 29
# Stats :{'session_count': 314, 'clicks': 955, 'clicks_by_session': 3.0414012738853504, 'unique_articles': 124, 'clicks_by_article': 7.701612903225806, 'norm_pop_mean': 0.008064516129032256, 'norm_pop_median': 0.0020942408376963353, 'gini_index': 0.7062742741491279, 'clicks_item_age_hours_mean': 11.485899069226292, 'clicks_item_age_hours_median': 9.525555555555556, 'clicks_item_age_hours_after_norm_mean': -0.04412781163460742, 'clicks_item_age_hours_after_norm_median': -0.015973476623743432}
# 29->29 # sessions: 314
#
# Processing hour 30
# Stats :{'session_count': 739, 'clicks': 2093, 'clicks_by_session': 2.832205683355886, 'unique_articles': 155, 'clicks_by_article': 13.503225806451614, 'norm_pop_mean': 0.0064516129032258064, 'norm_pop_median': 0.0009555661729574773, 'gini_index': 0.7935514673635444, 'clicks_item_age_hours_mean': 11.157861522535438, 'clicks_item_age_hours_median': 9.735833333333334, 'clicks_item_age_hours_after_norm_mean': -0.017127689186689672, 'clicks_item_age_hours_after_norm_median': -0.013623579652569268}
# 30->30 # sessions: 739
#
# Processing hour 31
# Stats :{'session_count': 1824, 'clicks': 5039, 'clicks_by_session': 2.762609649122807, 'unique_articles': 198, 'clicks_by_article': 25.449494949494948, 'norm_pop_mean': 0.005050505050505051, 'norm_pop_median': 0.00019845207382417147, 'gini_index': 0.8524548910793498, 'clicks_item_age_hours_mean': 11.326648750854476, 'clicks_item_age_hours_median': 10.306944444444444, 'clicks_item_age_hours_after_norm_mean': -0.01858284082087241, 'clicks_item_age_hours_after_norm_median': -0.01835738127045873}
# 31->31 # sessions: 1824
#
# Processing hour 32
# Stats :{'session_count': 2055, 'clicks': 5603, 'clicks_by_session': 2.7265206812652067, 'unique_articles': 215, 'clicks_by_article': 26.06046511627907, 'norm_pop_mean': 0.004651162790697673, 'norm_pop_median': 0.0003569516330537212, 'gini_index': 0.8374865612966029, 'clicks_item_age_hours_mean': 12.967785710036297, 'clicks_item_age_hours_median': 12.023333333333333, 'clicks_item_age_hours_after_norm_mean': -0.00942235824826102, 'clicks_item_age_hours_after_norm_median': -0.010057675603265233}
# 32->32 # sessions: 2055
#
# Processing hour 33
# Stats :{'session_count': 2493, 'clicks': 6939, 'clicks_by_session': 2.783393501805054, 'unique_articles': 298, 'clicks_by_article': 23.28523489932886, 'norm_pop_mean': 0.003355704697986577, 'norm_pop_median': 0.0002882259691598213, 'gini_index': 0.8566187018787955, 'clicks_item_age_hours_mean': 12.250268250308231, 'clicks_item_age_hours_median': 11.205555555555556, 'clicks_item_age_hours_after_norm_mean': -0.03686771824575932, 'clicks_item_age_hours_after_norm_median': -0.03426164794555998}
# 33->33 # sessions: 2493
#
# Processing hour 34
# Stats :{'session_count': 2329, 'clicks': 6235, 'clicks_by_session': 2.677114641477029, 'unique_articles': 274, 'clicks_by_article': 22.755474452554743, 'norm_pop_mean': 0.00364963503649635, 'norm_pop_median': 0.00032076984763432237, 'gini_index': 0.8512769319502466, 'clicks_item_age_hours_mean': 12.704123139980394, 'clicks_item_age_hours_median': 11.9475, 'clicks_item_age_hours_after_norm_mean': -0.020598973019932153, 'clicks_item_age_hours_after_norm_median': -0.018451436146842904}
# 34->34 # sessions: 2329
#
# Processing hour 35
# Stats :{'session_count': 1668, 'clicks': 4480, 'clicks_by_session': 2.6858513189448443, 'unique_articles': 309, 'clicks_by_article': 14.498381877022654, 'norm_pop_mean': 0.003236245954692557, 'norm_pop_median': 0.0004464285714285714, 'gini_index': 0.8202742120124472, 'clicks_item_age_hours_mean': 15.430234312996058, 'clicks_item_age_hours_median': 14.647777777777778, 'clicks_item_age_hours_after_norm_mean': -0.02607271583132695, 'clicks_item_age_hours_after_norm_median': -0.01342376771582598}
# 35->35 # sessions: 1668
#
# Processing hour 36
# Stats :{'session_count': 1719, 'clicks': 4560, 'clicks_by_session': 2.6527050610820244, 'unique_articles': 325, 'clicks_by_article': 14.03076923076923, 'norm_pop_mean': 0.003076923076923077, 'norm_pop_median': 0.0002192982456140351, 'gini_index': 0.8310337360801323, 'clicks_item_age_hours_mean': 14.450360745614036, 'clicks_item_age_hours_median': 13.732916666666668, 'clicks_item_age_hours_after_norm_mean': -0.028567002831481222, 'clicks_item_age_hours_after_norm_median': -0.023888278626000126}
# 36->36 # sessions: 1719
#
# Processing hour 37
# Stats :{'session_count': 2133, 'clicks': 5390, 'clicks_by_session': 2.5269573370839193, 'unique_articles': 310, 'clicks_by_article': 17.387096774193548, 'norm_pop_mean': 0.0032258064516129032, 'norm_pop_median': 0.00018552875695732838, 'gini_index': 0.855303128335697, 'clicks_item_age_hours_mean': 11.144991290455595, 'clicks_item_age_hours_median': 4.707083333333333, 'clicks_item_age_hours_after_norm_mean': -0.061000707129389674, 'clicks_item_age_hours_after_norm_median': -0.07084634521704007}
# 37->37 # sessions: 2133
#
# Processing hour 38
# Stats :{'session_count': 2977, 'clicks': 7419, 'clicks_by_session': 2.492106147127981, 'unique_articles': 387, 'clicks_by_article': 19.170542635658915, 'norm_pop_mean': 0.0025839793281653744, 'norm_pop_median': 0.00013478905512872354, 'gini_index': 0.8971489836674431, 'clicks_item_age_hours_mean': 8.257513254257056, 'clicks_item_age_hours_median': 1.6722222222222223, 'clicks_item_age_hours_after_norm_mean': -0.10642455243049014, 'clicks_item_age_hours_after_norm_median': -0.12619986614915016}
# 38->38 # sessions: 2977
#
# Processing hour 39
# Stats :{'session_count': 2947, 'clicks': 7549, 'clicks_by_session': 2.561588055649813, 'unique_articles': 386, 'clicks_by_article': 19.55699481865285, 'norm_pop_mean': 0.0025906735751295338, 'norm_pop_median': 0.00013246787653993907, 'gini_index': 0.8864218352722848, 'clicks_item_age_hours_mean': 9.160765038783657, 'clicks_item_age_hours_median': 2.3894444444444445, 'clicks_item_age_hours_after_norm_mean': -0.09073488525363742, 'clicks_item_age_hours_after_norm_median': -0.10040466221796053}
# 39->39 # sessions: 2947
#
# Processing hour 40
# Stats :{'session_count': 5037, 'clicks': 13103, 'clicks_by_session': 2.6013500099265436, 'unique_articles': 383, 'clicks_by_article': 34.21148825065274, 'norm_pop_mean': 0.0026109660574412533, 'norm_pop_median': 7.631840036632832e-05, 'gini_index': 0.92306168614617, 'clicks_item_age_hours_mean': 5.788858912717201, 'clicks_item_age_hours_median': 1.5402777777777779, 'clicks_item_age_hours_after_norm_mean': -0.16206836893008061, 'clicks_item_age_hours_after_norm_median': -0.24017619900393938}
# 40->40 # sessions: 5037
#
# Processing hour 41
# Stats :{'session_count': 8337, 'clicks': 22942, 'clicks_by_session': 2.7518291951541323, 'unique_articles': 393, 'clicks_by_article': 58.3765903307888, 'norm_pop_mean': 0.002544529262086514, 'norm_pop_median': 4.358817888588615e-05, 'gini_index': 0.9499658720877977, 'clicks_item_age_hours_mean': 3.5094412600858558, 'clicks_item_age_hours_median': 0.8786111111111111, 'clicks_item_age_hours_after_norm_mean': -0.25690551856642385, 'clicks_item_age_hours_after_norm_median': -0.33260632594482537}
# 41->41 # sessions: 8337
#
# Processing hour 42
# Stats :{'session_count': 9265, 'clicks': 26638, 'clicks_by_session': 2.8751214247166756, 'unique_articles': 389, 'clicks_by_article': 68.47814910025707, 'norm_pop_mean': 0.0025706940874035997, 'norm_pop_median': 3.7540355882573766e-05, 'gini_index': 0.9493844052945669, 'clicks_item_age_hours_mean': 3.540305171809733, 'clicks_item_age_hours_median': 1.2127777777777777, 'clicks_item_age_hours_after_norm_mean': -0.20106784433509398, 'clicks_item_age_hours_after_norm_median': -0.2845589747750266}
# 42->42 # sessions: 9265
#
# Processing hour 43
# Stats :{'session_count': 8320, 'clicks': 24584, 'clicks_by_session': 2.9548076923076922, 'unique_articles': 399, 'clicks_by_article': 61.6140350877193, 'norm_pop_mean': 0.002506265664160401, 'norm_pop_median': 4.067686300032541e-05, 'gini_index': 0.9466655977909869, 'clicks_item_age_hours_mean': 3.7724555944245783, 'clicks_item_age_hours_median': 1.7766666666666666, 'clicks_item_age_hours_after_norm_mean': -0.190686758105971, 'clicks_item_age_hours_after_norm_median': -0.19030337615355677}
# 43->43 # sessions: 8320
#
# Processing hour 44
# Stats :{'session_count': 5995, 'clicks': 17051, 'clicks_by_session': 2.844203502919099, 'unique_articles': 367, 'clicks_by_article': 46.46049046321526, 'norm_pop_mean': 0.0027247956403269754, 'norm_pop_median': 5.864758665180928e-05, 'gini_index': 0.9314467234748364, 'clicks_item_age_hours_mean': 5.229381789272703, 'clicks_item_age_hours_median': 2.7719444444444443, 'clicks_item_age_hours_after_norm_mean': -0.08501190960614972, 'clicks_item_age_hours_after_norm_median': -0.07806851422414769}
# 44->44 # sessions: 5995
#
# Processing hour 45
# Stats :{'session_count': 5430, 'clicks': 15224, 'clicks_by_session': 2.803683241252302, 'unique_articles': 381, 'clicks_by_article': 39.958005249343834, 'norm_pop_mean': 0.0026246719160104987, 'norm_pop_median': 6.568575932737782e-05, 'gini_index': 0.9196961414167212, 'clicks_item_age_hours_mean': 6.504287583201972, 'clicks_item_age_hours_median': 3.8023611111111113, 'clicks_item_age_hours_after_norm_mean': -0.05491677712567513, 'clicks_item_age_hours_after_norm_median': -0.055556317278052436}
# 45->45 # sessions: 5430
#
# Processing hour 46
# Stats :{'session_count': 6743, 'clicks': 18798, 'clicks_by_session': 2.787779919916951, 'unique_articles': 405, 'clicks_by_article': 46.41481481481482, 'norm_pop_mean': 0.0024691358024691358, 'norm_pop_median': 5.319714863283328e-05, 'gini_index': 0.9265726975352226, 'clicks_item_age_hours_mean': 6.23989784669767, 'clicks_item_age_hours_median': 4.203194444444444, 'clicks_item_age_hours_after_norm_mean': -0.11084013118701098, 'clicks_item_age_hours_after_norm_median': -0.09077146733598232}
# 46->46 # sessions: 6743
#
# Processing hour 47
# Stats :{'session_count': 7424, 'clicks': 20733, 'clicks_by_session': 2.792699353448276, 'unique_articles': 451, 'clicks_by_article': 45.971175166297115, 'norm_pop_mean': 0.0022172949002217295, 'norm_pop_median': 4.82322866927121e-05, 'gini_index': 0.9338151422449903, 'clicks_item_age_hours_mean': 5.368623745290671, 'clicks_item_age_hours_median': 3.8422222222222224, 'clicks_item_age_hours_after_norm_mean': -0.12937580069564245, 'clicks_item_age_hours_after_norm_median': -0.1593391201972328}
# 47->47 # sessions: 7424
#
# Processing hour 48
# Stats :{'session_count': 5534, 'clicks': 15889, 'clicks_by_session': 2.8711601011926273, 'unique_articles': 420, 'clicks_by_article': 37.83095238095238, 'norm_pop_mean': 0.002380952380952381, 'norm_pop_median': 6.293662282081944e-05, 'gini_index': 0.9247375385196006, 'clicks_item_age_hours_mean': 6.382076558905214, 'clicks_item_age_hours_median': 4.4, 'clicks_item_age_hours_after_norm_mean': -0.08767961892884107, 'clicks_item_age_hours_after_norm_median': -0.10517252334486586}
# 48->48 # sessions: 5534
# Processing hour 49
# Stats :{'session_count': 2740, 'clicks': 8153, 'clicks_by_session': 2.9755474452554744, 'unique_articles': 281, 'clicks_by_article': 29.01423487544484, 'norm_pop_mean': 0.0035587188612099642, 'norm_pop_median': 0.00012265423770391266, 'gini_index': 0.8890904501446487, 'clicks_item_age_hours_mean': 7.302424840208749, 'clicks_item_age_hours_median': 5.595, 'clicks_item_age_hours_after_norm_mean': -0.04424007562182279, 'clicks_item_age_hours_after_norm_median': -0.05280294943288544}
# 49->49 # sessions: 2740
#
# Processing hour 50
# Stats :{'session_count': 1248, 'clicks': 3593, 'clicks_by_session': 2.87900641025641, 'unique_articles': 201, 'clicks_by_article': 17.875621890547265, 'norm_pop_mean': 0.004975124378109452, 'norm_pop_median': 0.00027831895352073476, 'gini_index': 0.8482524737791507, 'clicks_item_age_hours_mean': 8.67941885456288, 'clicks_item_age_hours_median': 6.479166666666667, 'clicks_item_age_hours_after_norm_mean': -0.03200820713688207, 'clicks_item_age_hours_after_norm_median': -0.03134527367550775}
# 50->50 # sessions: 1248
#
# Processing hour 51
# Stats :{'session_count': 681, 'clicks': 2093, 'clicks_by_session': 3.0734214390602057, 'unique_articles': 193, 'clicks_by_article': 10.844559585492227, 'norm_pop_mean': 0.0051813471502590676, 'norm_pop_median': 0.0009555661729574773, 'gini_index': 0.7996900571357352, 'clicks_item_age_hours_mean': 9.90793531347881, 'clicks_item_age_hours_median': 8.053888888888888, 'clicks_item_age_hours_after_norm_mean': -0.03484274241386161, 'clicks_item_age_hours_after_norm_median': -0.020210755085937313}
# 51->51 # sessions: 681
#
# Processing hour 52
# Stats :{'session_count': 434, 'clicks': 1262, 'clicks_by_session': 2.9078341013824884, 'unique_articles': 117, 'clicks_by_article': 10.786324786324787, 'norm_pop_mean': 0.008547008547008546, 'norm_pop_median': 0.001584786053882726, 'gini_index': 0.7635011554566855, 'clicks_item_age_hours_mean': 10.487747402711744, 'clicks_item_age_hours_median': 8.430416666666666, 'clicks_item_age_hours_after_norm_mean': -0.014184480734951854, 'clicks_item_age_hours_after_norm_median': -0.00778816148642885}
# 52->52 # sessions: 434
#
# Processing hour 53
# Stats :{'session_count': 418, 'clicks': 1250, 'clicks_by_session': 2.9904306220095696, 'unique_articles': 138, 'clicks_by_article': 9.057971014492754, 'norm_pop_mean': 0.007246376811594203, 'norm_pop_median': 0.0008, 'gini_index': 0.7792811561328777, 'clicks_item_age_hours_mean': 11.772094444444447, 'clicks_item_age_hours_median': 7.455694444444445, 'clicks_item_age_hours_after_norm_mean': -0.021311863530105717, 'clicks_item_age_hours_after_norm_median': -0.014413307945067518}
# 53->53 # sessions: 418
#
# Processing hour 54
# Stats :{'session_count': 919, 'clicks': 2518, 'clicks_by_session': 2.73993471164309, 'unique_articles': 138, 'clicks_by_article': 18.246376811594203, 'norm_pop_mean': 0.007246376811594203, 'norm_pop_median': 0.0007942811755361397, 'gini_index': 0.83104257875305, 'clicks_item_age_hours_mean': 11.967275836201583, 'clicks_item_age_hours_median': 8.425694444444446, 'clicks_item_age_hours_after_norm_mean': -0.023375109645096075, 'clicks_item_age_hours_after_norm_median': -0.0264709312311166}
# 54->54 # sessions: 919
#
# Processing hour 55
# Stats :{'session_count': 2475, 'clicks': 6961, 'clicks_by_session': 2.8125252525252527, 'unique_articles': 215, 'clicks_by_article': 32.37674418604651, 'norm_pop_mean': 0.0046511627906976735, 'norm_pop_median': 0.0002873150409423933, 'gini_index': 0.8775069063393061, 'clicks_item_age_hours_mean': 12.379370859870038, 'clicks_item_age_hours_median': 9.455277777777777, 'clicks_item_age_hours_after_norm_mean': -0.02905384434623807, 'clicks_item_age_hours_after_norm_median': -0.04527246282339901}
# 55->55 # sessions: 2475
#
# Processing hour 56
# Stats :{'session_count': 3111, 'clicks': 8841, 'clicks_by_session': 2.841851494696239, 'unique_articles': 268, 'clicks_by_article': 32.98880597014925, 'norm_pop_mean': 0.0037313432835820895, 'norm_pop_median': 0.00022621875353466802, 'gini_index': 0.8887919571928, 'clicks_item_age_hours_mean': 13.211696452135897, 'clicks_item_age_hours_median': 12.39, 'clicks_item_age_hours_after_norm_mean': -0.025061842401595955, 'clicks_item_age_hours_after_norm_median': -0.02859207330959925}
# 56->56 # sessions: 3111
#
# Processing hour 57
# Stats :{'session_count': 3201, 'clicks': 9221, 'clicks_by_session': 2.880662293033427, 'unique_articles': 325, 'clicks_by_article': 28.372307692307693, 'norm_pop_mean': 0.003076923076923077, 'norm_pop_median': 0.00021689621516104545, 'gini_index': 0.8802048824541782, 'clicks_item_age_hours_mean': 14.174373742303167, 'clicks_item_age_hours_median': 13.680555555555555, 'clicks_item_age_hours_after_norm_mean': -0.02143668948181458, 'clicks_item_age_hours_after_norm_median': -0.017845843612723976}
# 57->57 # sessions: 3201
#
# Processing hour 58
# Stats :{'session_count': 2766, 'clicks': 7796, 'clicks_by_session': 2.818510484454085, 'unique_articles': 356, 'clicks_by_article': 21.89887640449438, 'norm_pop_mean': 0.0028089887640449437, 'norm_pop_median': 0.00012827090815802975, 'gini_index': 0.8733497717871199, 'clicks_item_age_hours_mean': 15.491244726640446, 'clicks_item_age_hours_median': 14.753888888888888, 'clicks_item_age_hours_after_norm_mean': -0.019482217262029845, 'clicks_item_age_hours_after_norm_median': -0.017244967578161463}
# 58->58 # sessions: 2766
#
# Processing hour 59
# Stats :{'session_count': 3046, 'clicks': 8158, 'clicks_by_session': 2.6782665791201574, 'unique_articles': 365, 'clicks_by_article': 22.350684931506848, 'norm_pop_mean': 0.0027397260273972603, 'norm_pop_median': 0.00012257906349595488, 'gini_index': 0.8815362333789006, 'clicks_item_age_hours_mean': 14.515898129988315, 'clicks_item_age_hours_median': 13.359861111111112, 'clicks_item_age_hours_after_norm_mean': -0.025813656375292475, 'clicks_item_age_hours_after_norm_median': -0.021247828803918494}
# 59->59 # sessions: 3046
#
# Processing hour 60
# Stats :{'session_count': 2407, 'clicks': 6297, 'clicks_by_session': 2.6161196510178644, 'unique_articles': 314, 'clicks_by_article': 20.054140127388536, 'norm_pop_mean': 0.0031847133757961785, 'norm_pop_median': 0.0001588057805304113, 'gini_index': 0.8681269703104436, 'clicks_item_age_hours_mean': 14.47121812856211, 'clicks_item_age_hours_median': 14.06, 'clicks_item_age_hours_after_norm_mean': -0.0244875190200677, 'clicks_item_age_hours_after_norm_median': -0.01394033767561874}
# 60->60 # sessions: 2407
#
# Processing hour 61
# Stats :{'session_count': 2077, 'clicks': 5386, 'clicks_by_session': 2.5931632161771785, 'unique_articles': 355, 'clicks_by_article': 15.171830985915493, 'norm_pop_mean': 0.0028169014084507044, 'norm_pop_median': 0.0001856665428889714, 'gini_index': 0.856654966857565, 'clicks_item_age_hours_mean': 14.213693784296746, 'clicks_item_age_hours_median': 14.615694444444443, 'clicks_item_age_hours_after_norm_mean': -0.032678085851606684, 'clicks_item_age_hours_after_norm_median': -0.014783478075044943}
# 61->61 # sessions: 2077
#
# Processing hour 62
# Stats :{'session_count': 2675, 'clicks': 6884, 'clicks_by_session': 2.573457943925234, 'unique_articles': 365, 'clicks_by_article': 18.86027397260274, 'norm_pop_mean': 0.0027397260273972603, 'norm_pop_median': 0.0001452643811737362, 'gini_index': 0.8771445384835567, 'clicks_item_age_hours_mean': 11.985897411065945, 'clicks_item_age_hours_median': 5.732638888888889, 'clicks_item_age_hours_after_norm_mean': -0.059466950514388925, 'clicks_item_age_hours_after_norm_median': -0.05057719846235063}
# 62->62 # sessions: 2675
#
# Processing hour 63
# Stats :{'session_count': 2353, 'clicks': 6048, 'clicks_by_session': 2.57033574160646, 'unique_articles': 357, 'clicks_by_article': 16.941176470588236, 'norm_pop_mean': 0.0028011204481792713, 'norm_pop_median': 0.00016534391534391533, 'gini_index': 0.8670042073736327, 'clicks_item_age_hours_mean': 12.879284290490887, 'clicks_item_age_hours_median': 6.5600000000000005, 'clicks_item_age_hours_after_norm_mean': -0.042946645212367456, 'clicks_item_age_hours_after_norm_median': -0.03738646447685577}
# 63->63 # sessions: 2353
#
# Processing hour 64
# Stats :{'session_count': 5161, 'clicks': 13607, 'clicks_by_session': 2.6365045533811275, 'unique_articles': 342, 'clicks_by_article': 39.78654970760234, 'norm_pop_mean': 0.0029239766081871343, 'norm_pop_median': 7.349158521349305e-05, 'gini_index': 0.9331800317264215, 'clicks_item_age_hours_mean': 5.472897038289153, 'clicks_item_age_hours_median': 0.5383333333333333, 'clicks_item_age_hours_after_norm_mean': -0.279161928148224, 'clicks_item_age_hours_after_norm_median': -0.4206906172208358}
# 64->64 # sessions: 5161
# Processing hour 65
# Stats :{'session_count': 5659, 'clicks': 14994, 'clicks_by_session': 2.649584732284856, 'unique_articles': 304, 'clicks_by_article': 49.32236842105263, 'norm_pop_mean': 0.003289473684210526, 'norm_pop_median': 0.00013338668800853674, 'gini_index': 0.9342223725557902, 'clicks_item_age_hours_mean': 5.991299593911651, 'clicks_item_age_hours_median': 1.4422222222222223, 'clicks_item_age_hours_after_norm_mean': -0.1941793636793079, 'clicks_item_age_hours_after_norm_median': -0.2962552284912074}
# 65->65 # sessions: 5659
#
# Processing hour 66
# Stats :{'session_count': 4866, 'clicks': 13015, 'clicks_by_session': 2.674681463214139, 'unique_articles': 307, 'clicks_by_article': 42.39413680781759, 'norm_pop_mean': 0.0032573289902280127, 'norm_pop_median': 7.68344218209758e-05, 'gini_index': 0.9252851563758827, 'clicks_item_age_hours_mean': 7.23144604516157, 'clicks_item_age_hours_median': 2.41, 'clicks_item_age_hours_after_norm_mean': -0.12950711062990136, 'clicks_item_age_hours_after_norm_median': -0.181484168855531}
# 66->66 # sessions: 4866
#
# Processing hour 67
# Stats :{'session_count': 4191, 'clicks': 11043, 'clicks_by_session': 2.6349319971367215, 'unique_articles': 317, 'clicks_by_article': 34.83596214511041, 'norm_pop_mean': 0.0031545741324921143, 'norm_pop_median': 9.055510278004166e-05, 'gini_index': 0.921237913142939, 'clicks_item_age_hours_mean': 8.064353159869983, 'clicks_item_age_hours_median': 3.281388888888889, 'clicks_item_age_hours_after_norm_mean': -0.08780307209988435, 'clicks_item_age_hours_after_norm_median': -0.11566327086671244}
# 67->67 # sessions: 4191
#
# Processing hour 68
# Stats :{'session_count': 3174, 'clicks': 8403, 'clicks_by_session': 2.6474480151228734, 'unique_articles': 243, 'clicks_by_article': 34.58024691358025, 'norm_pop_mean': 0.00411522633744856, 'norm_pop_median': 0.00011900511722004047, 'gini_index': 0.9020783769890668, 'clicks_item_age_hours_mean': 8.272155314900779, 'clicks_item_age_hours_median': 4.034722222222222, 'clicks_item_age_hours_after_norm_mean': -0.057233964987583555, 'clicks_item_age_hours_after_norm_median': -0.060593246854514365}
# 68->68 # sessions: 3174
#
# Processing hour 69
# Stats :{'session_count': 3005, 'clicks': 7741, 'clicks_by_session': 2.5760399334442594, 'unique_articles': 310, 'clicks_by_article': 24.970967741935485, 'norm_pop_mean': 0.0032258064516129032, 'norm_pop_median': 0.0001291822761917065, 'gini_index': 0.8967337708258781, 'clicks_item_age_hours_mean': 8.912638978598784, 'clicks_item_age_hours_median': 4.819444444444445, 'clicks_item_age_hours_after_norm_mean': -0.05995316324967968, 'clicks_item_age_hours_after_norm_median': -0.05007814198860467}
# 69->69 # sessions: 3005
#
# Processing hour 70
# Stats :{'session_count': 4667, 'clicks': 12320, 'clicks_by_session': 2.6398114420398544, 'unique_articles': 437, 'clicks_by_article': 28.19221967963387, 'norm_pop_mean': 0.0022883295194508005, 'norm_pop_median': 8.116883116883117e-05, 'gini_index': 0.9198835765180192, 'clicks_item_age_hours_mean': 6.913002773268402, 'clicks_item_age_hours_median': 2.1643055555555555, 'clicks_item_age_hours_after_norm_mean': -0.13681555947656127, 'clicks_item_age_hours_after_norm_median': -0.1682130499276022}
# 70->70 # sessions: 4667
#
# Processing hour 71
# Stats :{'session_count': 5452, 'clicks': 14759, 'clicks_by_session': 2.7070799706529716, 'unique_articles': 337, 'clicks_by_article': 43.795252225519285, 'norm_pop_mean': 0.0029673590504451044, 'norm_pop_median': 6.775526797208483e-05, 'gini_index': 0.9237367204488053, 'clicks_item_age_hours_mean': 5.921076348894493, 'clicks_item_age_hours_median': 1.5175, 'clicks_item_age_hours_after_norm_mean': -0.09487180870811435, 'clicks_item_age_hours_after_norm_median': -0.16716463633833817}
# 71->71 # sessions: 5452
#
# Processing hour 72
# Stats :{'session_count': 3677, 'clicks': 10364, 'clicks_by_session': 2.818602121294534, 'unique_articles': 371, 'clicks_by_article': 27.935309973045822, 'norm_pop_mean': 0.0026954177897574117, 'norm_pop_median': 9.648784253184099e-05, 'gini_index': 0.9044551885428345, 'clicks_item_age_hours_mean': 7.235474559372167, 'clicks_item_age_hours_median': 2.479722222222222, 'clicks_item_age_hours_after_norm_mean': -0.0916442864266955, 'clicks_item_age_hours_after_norm_median': -0.1107128963746221}
# 72->72 # sessions: 3677
#
# Processing hour 73
# Stats :{'session_count': 2061, 'clicks': 6002, 'clicks_by_session': 2.9121785540999516, 'unique_articles': 283, 'clicks_by_article': 21.208480565371026, 'norm_pop_mean': 0.0035335689045936395, 'norm_pop_median': 0.00016661112962345885, 'gini_index': 0.863960539433805, 'clicks_item_age_hours_mean': 7.5768049539042694, 'clicks_item_age_hours_median': 3.2044444444444444, 'clicks_item_age_hours_after_norm_mean': -0.041285257003858294, 'clicks_item_age_hours_after_norm_median': -0.04916557509864237}
# 73->73 # sessions: 2061
#
# Processing hour 74
# Stats :{'session_count': 933, 'clicks': 2837, 'clicks_by_session': 3.0407288317256165, 'unique_articles': 178, 'clicks_by_article': 15.938202247191011, 'norm_pop_mean': 0.005617977528089887, 'norm_pop_median': 0.0007049700387733521, 'gini_index': 0.8031886013901068, 'clicks_item_age_hours_mean': 9.450585418869705, 'clicks_item_age_hours_median': 4.429722222222222, 'clicks_item_age_hours_after_norm_mean': -0.017592719944868298, 'clicks_item_age_hours_after_norm_median': -0.02102956685738741}
# 74->74 # sessions: 933
#
# Processing hour 75
# Stats :{'session_count': 505, 'clicks': 1503, 'clicks_by_session': 2.976237623762376, 'unique_articles': 135, 'clicks_by_article': 11.133333333333333, 'norm_pop_mean': 0.007407407407407408, 'norm_pop_median': 0.0006653359946773121, 'gini_index': 0.7595278551878094, 'clicks_item_age_hours_mean': 10.197653766540984, 'clicks_item_age_hours_median': 5.331388888888889, 'clicks_item_age_hours_after_norm_mean': -0.027853062936574205, 'clicks_item_age_hours_after_norm_median': -0.019224633593406763}
# 75->75 # sessions: 505
#
# Processing hour 76
# Stats :{'session_count': 320, 'clicks': 921, 'clicks_by_session': 2.878125, 'unique_articles': 124, 'clicks_by_article': 7.42741935483871, 'norm_pop_mean': 0.008064516129032258, 'norm_pop_median': 0.0010857763300760044, 'gini_index': 0.718967807999192, 'clicks_item_age_hours_mean': 11.635869525877677, 'clicks_item_age_hours_median': 6.473333333333334, 'clicks_item_age_hours_after_norm_mean': -0.03220630871718741, 'clicks_item_age_hours_after_norm_median': -0.014612143112816892}
# 76->76 # sessions: 320
#
# Processing hour 77
# Stats :{'session_count': 341, 'clicks': 1021, 'clicks_by_session': 2.994134897360704, 'unique_articles': 116, 'clicks_by_article': 8.801724137931034, 'norm_pop_mean': 0.008620689655172414, 'norm_pop_median': 0.0009794319294809011, 'gini_index': 0.7193336451678473, 'clicks_item_age_hours_mean': 11.940341984982066, 'clicks_item_age_hours_median': 7.572222222222222, 'clicks_item_age_hours_after_norm_mean': -0.033558165992582024, 'clicks_item_age_hours_after_norm_median': -0.015906425904163024}
# 77->77 # sessions: 341
#
# Processing hour 78
# Stats :{'session_count': 743, 'clicks': 2148, 'clicks_by_session': 2.8909825033647376, 'unique_articles': 124, 'clicks_by_article': 17.322580645161292, 'norm_pop_mean': 0.008064516129032261, 'norm_pop_median': 0.000931098696461825, 'gini_index': 0.7815747565390176, 'clicks_item_age_hours_mean': 12.219952022553276, 'clicks_item_age_hours_median': 8.475000000000001, 'clicks_item_age_hours_after_norm_mean': -0.014629264054661242, 'clicks_item_age_hours_after_norm_median': -0.013452631186456555}
# 78->78 # sessions: 743
#
# Processing hour 79
# Stats :{'session_count': 1676, 'clicks': 4630, 'clicks_by_session': 2.7625298329355608, 'unique_articles': 190, 'clicks_by_article': 24.36842105263158, 'norm_pop_mean': 0.005263157894736842, 'norm_pop_median': 0.00043196544276457883, 'gini_index': 0.8369853346979562, 'clicks_item_age_hours_mean': 13.180594732421433, 'clicks_item_age_hours_median': 9.395555555555557, 'clicks_item_age_hours_after_norm_mean': -0.02513578549919173, 'clicks_item_age_hours_after_norm_median': -0.02973723507874719}
# 79->79 # sessions: 1676
#
# Processing hour 80
# Stats :{'session_count': 3056, 'clicks': 8400, 'clicks_by_session': 2.74869109947644, 'unique_articles': 246, 'clicks_by_article': 34.146341463414636, 'norm_pop_mean': 0.004065040650406504, 'norm_pop_median': 0.0002380952380952381, 'gini_index': 0.8736827323997939, 'clicks_item_age_hours_mean': 11.963920337301541, 'clicks_item_age_hours_median': 9.957777777777778, 'clicks_item_age_hours_after_norm_mean': -0.058274353071767905, 'clicks_item_age_hours_after_norm_median': -0.04452507071657591}
# 80->80 # sessions: 3056
#
# Processing hour 81
# Stats :{'session_count': 5004, 'clicks': 14311, 'clicks_by_session': 2.859912070343725, 'unique_articles': 339, 'clicks_by_article': 42.21533923303835, 'norm_pop_mean': 0.0029498525073746312, 'norm_pop_median': 6.987631891551953e-05, 'gini_index': 0.9066219451217674, 'clicks_item_age_hours_mean': 9.698901505446436, 'clicks_item_age_hours_median': 9.418611111111112, 'clicks_item_age_hours_after_norm_mean': -0.13324574214156382, 'clicks_item_age_hours_after_norm_median': -0.15368038880228116}
# 81->81 # sessions: 5004
#
# Processing hour 82
# Stats :{'session_count': 6186, 'clicks': 17295, 'clicks_by_session': 2.7958292919495635, 'unique_articles': 348, 'clicks_by_article': 49.69827586206897, 'norm_pop_mean': 0.0028735632183908046, 'norm_pop_median': 5.782017924255565e-05, 'gini_index': 0.9215484836156966, 'clicks_item_age_hours_mean': 8.804624233079593, 'clicks_item_age_hours_median': 1.6602777777777777, 'clicks_item_age_hours_after_norm_mean': -0.1382202182063233, 'clicks_item_age_hours_after_norm_median': -0.2176321892566601}
# 82->82 # sessions: 6186
#
# Processing hour 83
# Stats :{'session_count': 4830, 'clicks': 13159, 'clicks_by_session': 2.724430641821946, 'unique_articles': 395, 'clicks_by_article': 33.31392405063291, 'norm_pop_mean': 0.002531645569620253, 'norm_pop_median': 7.599361653621096e-05, 'gini_index': 0.9173183671686389, 'clicks_item_age_hours_mean': 10.432079438660466, 'clicks_item_age_hours_median': 2.647777777777778, 'clicks_item_age_hours_after_norm_mean': -0.11443071021266644, 'clicks_item_age_hours_after_norm_median': -0.17055786183687618}
# 83->83 # sessions: 4830
#
# Processing hour 84
# Stats :{'session_count': 3151, 'clicks': 8400, 'clicks_by_session': 2.6658203744842908, 'unique_articles': 311, 'clicks_by_article': 27.009646302250804, 'norm_pop_mean': 0.003215434083601286, 'norm_pop_median': 0.00011904761904761905, 'gini_index': 0.8933976409149068, 'clicks_item_age_hours_mean': 12.182602314814767, 'clicks_item_age_hours_median': 3.718611111111111, 'clicks_item_age_hours_after_norm_mean': -0.07798569221167388, 'clicks_item_age_hours_after_norm_median': -0.12251783786564945}
# 84->84 # sessions: 3151
#
# Processing hour 85
# Stats :{'session_count': 3031, 'clicks': 7889, 'clicks_by_session': 2.602771362586605, 'unique_articles': 367, 'clicks_by_article': 21.49591280653951, 'norm_pop_mean': 0.0027247956403269754, 'norm_pop_median': 0.00012675877804537965, 'gini_index': 0.8914368042428799, 'clicks_item_age_hours_mean': 11.956730046055725, 'clicks_item_age_hours_median': 4.470277777777778, 'clicks_item_age_hours_after_norm_mean': -0.06282482659753924, 'clicks_item_age_hours_after_norm_median': -0.08078761182110816}
# 85->85 # sessions: 3031
#
# Processing hour 86
# Stats :{'session_count': 5320, 'clicks': 13355, 'clicks_by_session': 2.5103383458646618, 'unique_articles': 386, 'clicks_by_article': 34.59844559585492, 'norm_pop_mean': 0.0025906735751295333, 'norm_pop_median': 7.487832272557094e-05, 'gini_index': 0.9306958438374939, 'clicks_item_age_hours_mean': 7.783329651815799, 'clicks_item_age_hours_median': 3.2016666666666667, 'clicks_item_age_hours_after_norm_mean': -0.14786142033456276, 'clicks_item_age_hours_after_norm_median': -0.17810237899753162}
# 86->86 # sessions: 5320
#
# Processing hour 87
# Stats :{'session_count': 4859, 'clicks': 12380, 'clicks_by_session': 2.5478493517184604, 'unique_articles': 420, 'clicks_by_article': 29.476190476190474, 'norm_pop_mean': 0.002380952380952381, 'norm_pop_median': 8.077544426494346e-05, 'gini_index': 0.9249761510777541, 'clicks_item_age_hours_mean': 8.739005631843488, 'clicks_item_age_hours_median': 2.2034722222222225, 'clicks_item_age_hours_after_norm_mean': -0.11132963232473274, 'clicks_item_age_hours_after_norm_median': -0.14797567063055903}
# 87->87 # sessions: 4859
#
# Processing hour 88
# Stats :{'session_count': 3699, 'clicks': 9569, 'clicks_by_session': 2.5869153825358207, 'unique_articles': 395, 'clicks_by_article': 24.225316455696202, 'norm_pop_mean': 0.002531645569620253, 'norm_pop_median': 0.00010450412791305256, 'gini_index': 0.9085684113219213, 'clicks_item_age_hours_mean': 9.896188937657497, 'clicks_item_age_hours_median': 3.102777777777778, 'clicks_item_age_hours_after_norm_mean': -0.06266369192160756, 'clicks_item_age_hours_after_norm_median': -0.08138621275106746}
# 88->88 # sessions: 3699
#
# Processing hour 89
# Stats :{'session_count': 4240, 'clicks': 11469, 'clicks_by_session': 2.704952830188679, 'unique_articles': 371, 'clicks_by_article': 30.91374663072776, 'norm_pop_mean': 0.0026954177897574125, 'norm_pop_median': 8.719155985700585e-05, 'gini_index': 0.9004025608228635, 'clicks_item_age_hours_mean': 10.529603593261092, 'clicks_item_age_hours_median': 3.7116666666666664, 'clicks_item_age_hours_after_norm_mean': -0.0632447168353491, 'clicks_item_age_hours_after_norm_median': -0.07131052249861114}
# 89->89 # sessions: 4240
#
# Processing hour 90
# ...
# 355->355 # sessions: 6072
#
# Processing hour 356
# Stats :{'session_count': 4990, 'clicks': 13120, 'clicks_by_session': 2.629258517034068, 'unique_articles': 411, 'clicks_by_article': 31.92214111922141, 'norm_pop_mean': 0.0024330900243309, 'norm_pop_median': 7.621951219512195e-05, 'gini_index': 0.9229693332783518, 'clicks_item_age_hours_mean': 13.7780633680555, 'clicks_item_age_hours_median': 1.4479166666666667, 'clicks_item_age_hours_after_norm_mean': -0.12023436842145582, 'clicks_item_age_hours_after_norm_median': -0.14807316573894305}
# 356->356 # sessions: 4990
#
# Processing hour 357
# Stats :{'session_count': 4456, 'clicks': 11561, 'clicks_by_session': 2.594479353680431, 'unique_articles': 332, 'clicks_by_article': 34.8222891566265, 'norm_pop_mean': 0.003012048192771084, 'norm_pop_median': 8.649770781074301e-05, 'gini_index': 0.9178592225932897, 'clicks_item_age_hours_mean': 11.730429389037868, 'clicks_item_age_hours_median': 2.0305555555555554, 'clicks_item_age_hours_after_norm_mean': -0.08889136751261184, 'clicks_item_age_hours_after_norm_median': -0.07391980310859787}
# 357->357 # sessions: 4456
#
# Processing hour 358
# Stats :{'session_count': 4585, 'clicks': 12002, 'clicks_by_session': 2.6176663031624865, 'unique_articles': 408, 'clicks_by_article': 29.416666666666668, 'norm_pop_mean': 0.0024509803921568627, 'norm_pop_median': 8.331944675887353e-05, 'gini_index': 0.9197221205370172, 'clicks_item_age_hours_mean': 13.39744797163436, 'clicks_item_age_hours_median': 2.852222222222222, 'clicks_item_age_hours_after_norm_mean': -0.06477425376144548, 'clicks_item_age_hours_after_norm_median': -0.04510150206396187}
# 358->358 # sessions: 4585
#
# Processing hour 359
# Stats :{'session_count': 4386, 'clicks': 12004, 'clicks_by_session': 2.736890104879161, 'unique_articles': 391, 'clicks_by_article': 30.70076726342711, 'norm_pop_mean': 0.0025575447570332483, 'norm_pop_median': 8.330556481172943e-05, 'gini_index': 0.9104722968753445, 'clicks_item_age_hours_mean': 15.598436192565416, 'clicks_item_age_hours_median': 4.042361111111111, 'clicks_item_age_hours_after_norm_mean': -0.058030340284930045, 'clicks_item_age_hours_after_norm_median': -0.03536604647951538}
# 359->359 # sessions: 4386
#
# Processing hour 360
# Stats :{'session_count': 3295, 'clicks': 8891, 'clicks_by_session': 2.698330804248862, 'unique_articles': 350, 'clicks_by_article': 25.402857142857144, 'norm_pop_mean': 0.002857142857142857, 'norm_pop_median': 0.00011247328759419637, 'gini_index': 0.9028375392491326, 'clicks_item_age_hours_mean': 16.964010734950488, 'clicks_item_age_hours_median': 4.497222222222222, 'clicks_item_age_hours_after_norm_mean': -0.05134755322997355, 'clicks_item_age_hours_after_norm_median': -0.043657261680837285}
# 360->360 # sessions: 3295
#
# Processing hour 361
# Stats :{'session_count': 1528, 'clicks': 4229, 'clicks_by_session': 2.767670157068063, 'unique_articles': 270, 'clicks_by_article': 15.662962962962963, 'norm_pop_mean': 0.003703703703703704, 'norm_pop_median': 0.00023646252069047056, 'gini_index': 0.8658618165417846, 'clicks_item_age_hours_mean': 18.525303460234877, 'clicks_item_age_hours_median': 5.162222222222222, 'clicks_item_age_hours_after_norm_mean': -0.020948036579364237, 'clicks_item_age_hours_after_norm_median': -0.02141090511141463}
# 361->361 # sessions: 1528
#
# Processing hour 362
# Stats :{'session_count': 602, 'clicks': 1752, 'clicks_by_session': 2.910299003322259, 'unique_articles': 151, 'clicks_by_article': 11.602649006622517, 'norm_pop_mean': 0.00662251655629139, 'norm_pop_median': 0.0005707762557077625, 'gini_index': 0.7855771240482866, 'clicks_item_age_hours_mean': 21.400301877219636, 'clicks_item_age_hours_median': 6.894722222222223, 'clicks_item_age_hours_after_norm_mean': -0.015949718648466425, 'clicks_item_age_hours_after_norm_median': -0.010657044164481488}
# 362->362 # sessions: 602
#
# Processing hour 363
# Stats :{'session_count': 324, 'clicks': 962, 'clicks_by_session': 2.9691358024691357, 'unique_articles': 131, 'clicks_by_article': 7.343511450381679, 'norm_pop_mean': 0.007633587786259542, 'norm_pop_median': 0.0010395010395010396, 'gini_index': 0.7354430138333578, 'clicks_item_age_hours_mean': 25.19447476322479, 'clicks_item_age_hours_median': 7.832222222222223, 'clicks_item_age_hours_after_norm_mean': -0.021312626045250672, 'clicks_item_age_hours_after_norm_median': -0.009202014176902454}
# 363->363 # sessions: 324
#
# Processing hour 364
# Stats :{'session_count': 250, 'clicks': 731, 'clicks_by_session': 2.924, 'unique_articles': 113, 'clicks_by_article': 6.469026548672566, 'norm_pop_mean': 0.008849557522123892, 'norm_pop_median': 0.0013679890560875513, 'gini_index': 0.7104342411836221, 'clicks_item_age_hours_mean': 29.755533135734893, 'clicks_item_age_hours_median': 9.004722222222222, 'clicks_item_age_hours_after_norm_mean': -0.01088098963304515, 'clicks_item_age_hours_after_norm_median': -0.008451888444497404}
# 364->364 # sessions: 250
#
# Processing hour 365
# Stats :{'session_count': 277, 'clicks': 840, 'clicks_by_session': 3.032490974729242, 'unique_articles': 117, 'clicks_by_article': 7.17948717948718, 'norm_pop_mean': 0.008547008547008544, 'norm_pop_median': 0.0011904761904761906, 'gini_index': 0.7283882742375438, 'clicks_item_age_hours_mean': 24.285432539682564, 'clicks_item_age_hours_median': 10.206944444444446, 'clicks_item_age_hours_after_norm_mean': -0.019890975302273517, 'clicks_item_age_hours_after_norm_median': -0.007352266465894005}
# 365->365 # sessions: 277
#
# Processing hour 366
# Stats :{'session_count': 658, 'clicks': 1894, 'clicks_by_session': 2.878419452887538, 'unique_articles': 159, 'clicks_by_article': 11.91194968553459, 'norm_pop_mean': 0.006289308176100628, 'norm_pop_median': 0.0005279831045406547, 'gini_index': 0.8141433034251593, 'clicks_item_age_hours_mean': 22.0922549278423, 'clicks_item_age_hours_median': 10.013194444444444, 'clicks_item_age_hours_after_norm_mean': -0.015124065162849918, 'clicks_item_age_hours_after_norm_median': -0.015398979027121618}
# 366->366 # sessions: 658
#
# Processing hour 367
# Stats :{'session_count': 2297, 'clicks': 6450, 'clicks_by_session': 2.808010448410971, 'unique_articles': 218, 'clicks_by_article': 29.587155963302752, 'norm_pop_mean': 0.0045871559633027525, 'norm_pop_median': 0.000310077519379845, 'gini_index': 0.8663124945580676, 'clicks_item_age_hours_mean': 16.784717312661492, 'clicks_item_age_hours_median': 9.513333333333334, 'clicks_item_age_hours_after_norm_mean': -0.03858491211625246, 'clicks_item_age_hours_after_norm_median': -0.04072416812408583}
# 367->367 # sessions: 2297
#
# Processing hour 368
# Stats :{'session_count': 3171, 'clicks': 8893, 'clicks_by_session': 2.804478082623778, 'unique_articles': 291, 'clicks_by_article': 30.560137457044675, 'norm_pop_mean': 0.003436426116838488, 'norm_pop_median': 0.00011244799280332846, 'gini_index': 0.8827159697008827, 'clicks_item_age_hours_mean': 18.3842875794945, 'clicks_item_age_hours_median': 10.40638888888889, 'clicks_item_age_hours_after_norm_mean': -0.03917788362112005, 'clicks_item_age_hours_after_norm_median': -0.04618569599051279}
# 368->368 # sessions: 3171
#
# Processing hour 369
# Stats :{'session_count': 2896, 'clicks': 8212, 'clicks_by_session': 2.835635359116022, 'unique_articles': 356, 'clicks_by_article': 23.06741573033708, 'norm_pop_mean': 0.0028089887640449437, 'norm_pop_median': 0.00012177301509985388, 'gini_index': 0.8784062225585003, 'clicks_item_age_hours_mean': 23.397954145694694, 'clicks_item_age_hours_median': 11.850000000000001, 'clicks_item_age_hours_after_norm_mean': -0.0275407535096081, 'clicks_item_age_hours_after_norm_median': -0.029496794728110398}
# 369->369 # sessions: 2896
#
# Processing hour 370
# Stats :{'session_count': 2779, 'clicks': 7839, 'clicks_by_session': 2.820798848506657, 'unique_articles': 362, 'clicks_by_article': 21.654696132596683, 'norm_pop_mean': 0.0027624309392265192, 'norm_pop_median': 0.00012756729174639623, 'gini_index': 0.8719411147031553, 'clicks_item_age_hours_mean': 24.45213193292793, 'clicks_item_age_hours_median': 12.453888888888889, 'clicks_item_age_hours_after_norm_mean': -0.0267548721224145, 'clicks_item_age_hours_after_norm_median': -0.02265910822413474}
# 370->370 # sessions: 2779
#
# Processing hour 371
# Stats :{'session_count': 3049, 'clicks': 8309, 'clicks_by_session': 2.7251557887832076, 'unique_articles': 345, 'clicks_by_article': 24.08405797101449, 'norm_pop_mean': 0.002898550724637681, 'norm_pop_median': 0.00012035142616440005, 'gini_index': 0.886269296462736, 'clicks_item_age_hours_mean': 19.90297649135475, 'clicks_item_age_hours_median': 10.743333333333334, 'clicks_item_age_hours_after_norm_mean': -0.06672459576887546, 'clicks_item_age_hours_after_norm_median': -0.06301757700712055}
# 371->371 # sessions: 3049
#
# Processing hour 372
# Stats :{'session_count': 3777, 'clicks': 9901, 'clicks_by_session': 2.621392639661107, 'unique_articles': 367, 'clicks_by_article': 26.978201634877383, 'norm_pop_mean': 0.0027247956403269754, 'norm_pop_median': 0.000100999899000101, 'gini_index': 0.8972495267369491, 'clicks_item_age_hours_mean': 20.715046908841977, 'clicks_item_age_hours_median': 4.8502777777777775, 'clicks_item_age_hours_after_norm_mean': -0.09201728658932079, 'clicks_item_age_hours_after_norm_median': -0.11372491785498061}
# 372->372 # sessions: 3777
#
# Processing hour 373
# Stats :{'session_count': 2998, 'clicks': 7739, 'clicks_by_session': 2.5813875917278186, 'unique_articles': 377, 'clicks_by_article': 20.52785145888594, 'norm_pop_mean': 0.002652519893899204, 'norm_pop_median': 0.0001292156609381057, 'gini_index': 0.8838392323508631, 'clicks_item_age_hours_mean': 23.08014447028759, 'clicks_item_age_hours_median': 2.9694444444444446, 'clicks_item_age_hours_after_norm_mean': -0.059061182543859156, 'clicks_item_age_hours_after_norm_median': -0.07233755395331205}
# 373->373 # sessions: 2998
#
# Processing hour 374
# Stats :{'session_count': 3241, 'clicks': 8386, 'clicks_by_session': 2.587473002159827, 'unique_articles': 432, 'clicks_by_article': 19.412037037037038, 'norm_pop_mean': 0.0023148148148148147, 'norm_pop_median': 0.00011924636298592893, 'gini_index': 0.891560337231332, 'clicks_item_age_hours_mean': 20.84953788721956, 'clicks_item_age_hours_median': 2.515833333333333, 'clicks_item_age_hours_after_norm_mean': -0.07652318005327952, 'clicks_item_age_hours_after_norm_median': -0.0930582676652464}
# 374->374 # sessions: 3241
#
# Processing hour 375
# Stats :{'session_count': 4018, 'clicks': 10522, 'clicks_by_session': 2.618715778994525, 'unique_articles': 399, 'clicks_by_article': 26.370927318295738, 'norm_pop_mean': 0.002506265664160401, 'norm_pop_median': 9.503896597605019e-05, 'gini_index': 0.9027615597011811, 'clicks_item_age_hours_mean': 17.660275639400986, 'clicks_item_age_hours_median': 1.8741666666666665, 'clicks_item_age_hours_after_norm_mean': -0.10895172156327283, 'clicks_item_age_hours_after_norm_median': -0.13189339517996787}
# 375->375 # sessions: 4018
#
# Processing hour 376
# Stats :{'session_count': 4180, 'clicks': 11348, 'clicks_by_session': 2.7148325358851673, 'unique_articles': 444, 'clicks_by_article': 25.55855855855856, 'norm_pop_mean': 0.0022522522522522522, 'norm_pop_median': 8.812125484666901e-05, 'gini_index': 0.9051839103182263, 'clicks_item_age_hours_mean': 17.408868033525277, 'clicks_item_age_hours_median': 1.9972222222222222, 'clicks_item_age_hours_after_norm_mean': -0.09522697943941848, 'clicks_item_age_hours_after_norm_median': -0.1144973530425992}
# 376->376 # sessions: 4180
#
# Processing hour 377
# Stats :{'session_count': 5970, 'clicks': 17113, 'clicks_by_session': 2.866499162479062, 'unique_articles': 418, 'clicks_by_article': 40.94019138755981, 'norm_pop_mean': 0.0023923444976076554, 'norm_pop_median': 5.843510781277391e-05, 'gini_index': 0.9258907222975801, 'clicks_item_age_hours_mean': 12.932442749826222, 'clicks_item_age_hours_median': 1.8291666666666666, 'clicks_item_age_hours_after_norm_mean': -0.16649526679126, 'clicks_item_age_hours_after_norm_median': -0.18696078106764533}
# 377->377 # sessions: 5970
#
# Processing hour 378
# Stats :{'session_count': 6464, 'clicks': 18563, 'clicks_by_session': 2.871751237623762, 'unique_articles': 411, 'clicks_by_article': 45.1654501216545, 'norm_pop_mean': 0.0024330900243309, 'norm_pop_median': 5.387060281204547e-05, 'gini_index': 0.9294571658694273, 'clicks_item_age_hours_mean': 12.216028030670362, 'clicks_item_age_hours_median': 2.1455555555555557, 'clicks_item_age_hours_after_norm_mean': -0.1464033549537346, 'clicks_item_age_hours_after_norm_median': -0.19033017996479915}
# 378->378 # sessions: 6464
#
# Processing hour 379
# Stats :{'session_count': 4540, 'clicks': 12731, 'clicks_by_session': 2.8041850220264317, 'unique_articles': 413, 'clicks_by_article': 30.825665859564165, 'norm_pop_mean': 0.002421307506053269, 'norm_pop_median': 7.854842510407666e-05, 'gini_index': 0.9121366436661577, 'clicks_item_age_hours_mean': 14.457467533317612, 'clicks_item_age_hours_median': 3.0225, 'clicks_item_age_hours_after_norm_mean': -0.07353773810220132, 'clicks_item_age_hours_after_norm_median': -0.10645049106431036}
# 379->379 # sessions: 4540
#
# Processing hour 380
# Stats :{'session_count': 4479, 'clicks': 12193, 'clicks_by_session': 2.7222594329091314, 'unique_articles': 378, 'clicks_by_article': 32.25661375661376, 'norm_pop_mean': 0.0026455026455026454, 'norm_pop_median': 8.201427048306405e-05, 'gini_index': 0.9148841571897292, 'clicks_item_age_hours_mean': 13.738111917584831, 'clicks_item_age_hours_median': 3.018611111111111, 'clicks_item_age_hours_after_norm_mean': -0.12090821048416514, 'clicks_item_age_hours_after_norm_median': -0.1296567979533762}
# 380->380 # sessions: 4479
#
# Processing hour 381
# Stats :{'session_count': 4361, 'clicks': 12002, 'clicks_by_session': 2.7521210731483605, 'unique_articles': 416, 'clicks_by_article': 28.85096153846154, 'norm_pop_mean': 0.002403846153846154, 'norm_pop_median': 8.331944675887353e-05, 'gini_index': 0.9068067972239051, 'clicks_item_age_hours_mean': 16.001235951415463, 'clicks_item_age_hours_median': 3.715138888888889, 'clicks_item_age_hours_after_norm_mean': -0.08675033065163304, 'clicks_item_age_hours_after_norm_median': -0.0987734824819975}
# 381->381 # sessions: 4361
#
# Processing hour 382
# Stats :{'session_count': 4951, 'clicks': 13635, 'clicks_by_session': 2.7539890931125024, 'unique_articles': 416, 'clicks_by_article': 32.77644230769231, 'norm_pop_mean': 0.002403846153846154, 'norm_pop_median': 7.334066740007334e-05, 'gini_index': 0.908610299246204, 'clicks_item_age_hours_mean': 15.95725430876428, 'clicks_item_age_hours_median': 3.986388888888889, 'clicks_item_age_hours_after_norm_mean': -0.08229151326489806, 'clicks_item_age_hours_after_norm_median': -0.08895779778459734}
# 382->382 # sessions: 4951
#
# Processing hour 383
# Stats :{'session_count': 5539, 'clicks': 15386, 'clicks_by_session': 2.777757717999639, 'unique_articles': 384, 'clicks_by_article': 40.067708333333336, 'norm_pop_mean': 0.0026041666666666665, 'norm_pop_median': 6.499415052645263e-05, 'gini_index': 0.9146674187843884, 'clicks_item_age_hours_mean': 15.927708847870493, 'clicks_item_age_hours_median': 3.4159722222222224, 'clicks_item_age_hours_after_norm_mean': -0.08849355953349014, 'clicks_item_age_hours_after_norm_median': -0.10771407845047637}
# 383->383 # sessions: 5539
#
# Processing hour 384
# Stats :{'session_count': 3936, 'clicks': 11120, 'clicks_by_session': 2.8252032520325203, 'unique_articles': 379, 'clicks_by_article': 29.34036939313984, 'norm_pop_mean': 0.002638522427440633, 'norm_pop_median': 8.992805755395684e-05, 'gini_index': 0.9015954508848255, 'clicks_item_age_hours_mean': 17.048282199240518, 'clicks_item_age_hours_median': 3.9166666666666665, 'clicks_item_age_hours_after_norm_mean': -0.07117059938487155, 'clicks_item_age_hours_after_norm_median': -0.06843737486124399}
# 384->384 # sessions: 3936

# %% [markdown]
# ### Checking outputs

# %%
train_df = pd.read_parquet(os.path.join(OUTPUT_PATH, '0001/train.parquet'))
len(train_df)
# Out:
# 2239

# %%
train_df.columns
# Out:
# Index(['session_id', 'session_size', 'session_start', 'user_id',
#        '_elapsed_ms_since_last_click', 'active_time_secs', 'article_id',
#        'city', 'country', 'device', 'os', 'referrer_class', 'region',
#        'timestamp', 'url', 'category0_encoded', 'category1_encoded',
#        'author_encoded', 'item_age_hours', 'hour_sin', 'hour_cos',
#        'weekday_sin', 'weekday_cos', 'item_age_hours_norm'],
#       dtype='object')

# %%
train_df.head()
# Out:
#         session_id  session_size  session_start  \
# 0  148322520900340             2  1483225209000
# 1  148322521000195             2  1483225210000
# 2  148322523500284             2  1483225235000
# 3  148322523600331             2  1483225236000
# 4  148322523900427             2  1483225239000
#
#                                        user_id  \
# 0    cx:221xclq7aa1yx2slhf0xq7svbf:l1m6d375szc
# 1             cx:ikr4x9pbm4bgz3kh:tw6xssyxkj15
# 2            cx:insyehp3a0zmucrw:3iuy03ssah3gs
# 3  cx:101hv49lafias30hxmt0tt8am0:3qw2ysixhcbwy
# 4            cx:i946i2jhoixihtyu:1ad4eauxl3fq7
#
#                  _elapsed_ms_since_last_click active_time_secs  \
# 0   [-0.575991661295168, -0.5052628777427455]             [92]
# 1   [-0.575991661295168, -0.5358877118582274]             None
# 2   [-0.575991661295168, -0.3915134938852414]             [47]
# 3  [-0.575991661295168, -0.34411791727794805]          [17, 2]
# 4   [-0.575991661295168, -0.4425548840777112]        [35, 139]
#
#        article_id        city country  device  ...  \
# 0  [45691, 11117]      [3, 3]  [2, 2]  [4, 4]  ...
# 1   [45691, 1763]      [3, 3]  [2, 2]  [4, 4]  ...
# 2  [11117, 45691]      [2, 2]  [2, 2]  [2, 2]  ...
# 3   [7090, 44743]  [644, 644]  [3, 3]  [3, 3]  ...
# 4  [45691, 30346]      [3, 3]  [2, 2]  [2, 2]  ...
#
#                                                  url category0_encoded  \
# 0  [http://www.adressa.no/nyheter/2016/12/31/Se-l...            [2, 2]
# 1  [http://www.adressa.no/nyheter/2016/12/31/Se-l...            [2, 5]
# 2  [http://www.adressa.no/nyheter/trondheim/2016/...            [2, 2]
# 3  [http://www.adressa.no/kamera/article7186931.e...          [27, 27]
# 4  [http://www.adressa.no/nyheter/2016/12/31/Se-l...            [2, 5]
#
#   category1_encoded author_encoded                  item_age_hours  \
# 0            [1, 2]        [4, 47]                      [0.0, 0.0]
# 1           [1, 53]        [4, 60]    [0.0002777777777777778, 0.0]
# 2            [2, 1]        [47, 4]  [-0.01972222222222222, 0.0775]
# 3            [1, 1]     [100, 100]                      [0.0, 0.0]
# 4            [1, 6]        [4, 31]     [0.008333333333333333, 0.0]
#
#                                    hour_sin  \
# 0  [0.9659258940477027, 0.9659258940477027]
# 1  [0.9659258940477027, 0.9659258940477027]
# 2  [0.9659258940477027, 0.9659258940477027]
# 3  [0.9659258940477027, 0.9659258940477027]
# 4  [0.9659258940477027, 0.9659258940477027]
#
#                                      hour_cos  \
# 0  [0.25881879222372195, 0.25881879222372195]
# 1  [0.25881879222372195, 0.25881879222372195]
# 2  [0.25881879222372195, 0.25881879222372195]
# 3  [0.25881879222372195, 0.25881879222372195]
# 4  [0.25881879222372195, 0.25881879222372195]
#
#                                       weekday_sin  \
# 0  [8.975979006501141e-07, 8.975979006501141e-07]
# 1  [8.975979006501141e-07, 8.975979006501141e-07]
# 2  [8.975979006501141e-07, 8.975979006501141e-07]
# 3  [8.975979006501141e-07, 8.975979006501141e-07]
# 4  [8.975979006501141e-07, 8.975979006501141e-07]
#
#                                 weekday_cos  \
# 0  [0.9999999999995972, 0.9999999999995972]
# 1  [0.9999999999995972, 0.9999999999995972]
# 2  [0.9999999999995972, 0.9999999999995972]
# 3  [0.9999999999995972, 0.9999999999995972]
# 4  [0.9999999999995972, 0.9999999999995972]
#
#                           item_age_hours_norm
# 0    [-1.083718732685902, -1.083718732685902]
# 1   [-1.0817379171796213, -1.083718732685902]
# 2  [-1.1209269983636971, -0.8643317194776033]
# 3    [-1.083718732685902, -1.083718732685902]
# 4   [-1.0529935942684951, -1.083718732685902]
#
# [5 rows x 24 columns]

# %%
valid_df = pd.read_parquet(os.path.join(OUTPUT_PATH, '0001/valid.parquet'))
len(valid_df)
# Out:
# 1119

# %%
test_df = pd.read_parquet(os.path.join(OUTPUT_PATH, '0001/test.parquet'))
len(test_df)
# Out:
# 1120

# %%
assert not (valid_df['session_id'].isin(test_df['session_id'])).any()
