# %%
import pandas as pd
import os
import gc

# %%
INPUT_PATH = '/mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet'
OUTPUT_PATH = '/mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split'
# !mkdir -p $OUTPUT_PATH

# %%
def fix_event_timestamp(event_ts_sequence):
    MAXIMUM_SESSION_DURATION_SECS = 60 * 120
    DEFAULT_ELAPSED_SECS_BETWEEN_INTERACTIONS = 60
    min_event_ts = min([e for e in event_ts_sequence if e != 0])
    max_event_ts = max(event_ts_sequence)

    if max_event_ts <= min_event_ts + MAXIMUM_SESSION_DURATION_SECS:
        return event_ts_sequence

    else:
        last_ts = None

        result = []
        for etime in event_ts_sequence:
            if etime > min_event_ts + MAXIMUM_SESSION_DURATION_SECS:
                etime = last_ts + DEFAULT_ELAPSED_SECS_BETWEEN_INTERACTIONS
            last_ts = etime
            result.append(etime)

        return result

# %%
def split_train_eval_parquet_file(sessions_df, parquet_path, perc_valid_set, perc_test_set):
    #sessions_df = pd.read_parquet(parquet_path)

    # Shuffling the order of sesions
    sessions_df = sessions_df.sample(frac=1).reset_index(drop=True)

    dataset_size = len(sessions_df)

    valid_set_size = int(dataset_size * perc_valid_set)
    test_set_size = int(dataset_size * perc_test_set)
    train_set_limit = dataset_size - valid_set_size - test_set_size

    train_df = sessions_df[:train_set_limit]
    valid_df = sessions_df[train_set_limit:train_set_limit+valid_set_size]
    test_df = sessions_df[train_set_limit+valid_set_size:dataset_size]

    try:

        # Sorting the sessions by start time
        train_df.sort_values("session_start_ts", inplace=True)
        valid_df.sort_values("session_start_ts", inplace=True)
        test_df.sort_values("session_start_ts", inplace=True)

        output_train_path = parquet_path.replace("-full.parquet", "-train.parquet")
        output_valid_path = parquet_path.replace("-full.parquet", "-valid.parquet")
        output_test_path = parquet_path.replace("-full.parquet", "-test.parquet")

        print('Saving train set to {}'.format(output_train_path))
        train_df.to_parquet(output_train_path)
        
        print('Saving valid set to {}'.format(output_valid_path))
        valid_df.to_parquet(output_valid_path)
        
        print('Saving test set to {}'.format(output_test_path))
        test_df.to_parquet(output_test_path)

    finally:
        del sessions_df
        del train_df
        del valid_df
        del test_df
        gc.collect()

# %%
for sessions_day_dir in sorted(os.listdir(INPUT_PATH)):
    if os.path.isdir(os.path.join(INPUT_PATH,sessions_day_dir)):
        print('Processing day: {}'.format(sessions_day_dir))
        
        dir_files = os.listdir(os.path.join(INPUT_PATH,sessions_day_dir))
        #Ignoring .crc hidden file
        parquet_name = list([f for f in dir_files if not f.startswith('.')])[0]
        parquet_name_full_path = os.path.join(INPUT_PATH, sessions_day_dir, parquet_name)
        print('Reading original file: '+parquet_name_full_path)
        pd_full = pd.read_parquet(parquet_name_full_path)
                
        # Temporary, as the event timestamps from some rare items of the pre-processed dataset are many days after the session start
        #But, fixing timestamp at this point really is not considered for training
        #pd_full["sess_etime_seq"] = pd_full["sess_etime_seq"].apply(fix_event_timestamp)
        
        print('Saving original file...')
        output_parquet_file = os.path.join(OUTPUT_PATH, sessions_day_dir+'-full.parquet')
        pd_full.to_parquet(output_parquet_file)
        
        print('Spliting train and test files...')
        split_train_eval_parquet_file(pd_full, output_parquet_file, perc_valid_set=0.1, perc_test_set=0.1)  
        
        print('')
# Out:
# Processing day: session_start_date=2019-10-01
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-01/part-00066-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-01-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-01-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-01-test.parquet
#
# Processing day: session_start_date=2019-10-02
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-02/part-00149-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-02-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-02-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-02-test.parquet
#
# Processing day: session_start_date=2019-10-03
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-03/part-00026-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-03-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-03-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-03-test.parquet
#
# Processing day: session_start_date=2019-10-04
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-04/part-00045-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-04-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-04-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-04-test.parquet
#
# Processing day: session_start_date=2019-10-05
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-05/part-00040-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-05-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-05-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-05-test.parquet
#
# Processing day: session_start_date=2019-10-06
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-06/part-00017-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-06-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-06-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-06-test.parquet
#
# Processing day: session_start_date=2019-10-07
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-07/part-00191-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-07-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-07-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-07-test.parquet
#
# Processing day: session_start_date=2019-10-08
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-08/part-00092-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-08-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-08-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-08-test.parquet
#
# Processing day: session_start_date=2019-10-09
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-09/part-00052-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-09-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-09-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-09-test.parquet
#
# Processing day: session_start_date=2019-10-10
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-10/part-00043-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-10-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-10-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-10-test.parquet
#
# Processing day: session_start_date=2019-10-11
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-11/part-00078-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-11-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-11-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-11-test.parquet
#
# Processing day: session_start_date=2019-10-12
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-12/part-00033-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-12-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-12-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-12-test.parquet
#
# Processing day: session_start_date=2019-10-13
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-13/part-00153-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-13-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-13-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-13-test.parquet
#
# Processing day: session_start_date=2019-10-14
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-14/part-00049-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-14-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-14-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-14-test.parquet
#
# Processing day: session_start_date=2019-10-15
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-15/part-00173-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-15-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-15-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-15-test.parquet
#
# Processing day: session_start_date=2019-10-16
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-16/part-00095-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-16-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-16-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-16-test.parquet
#
# Processing day: session_start_date=2019-10-17
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-17/part-00102-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-17-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-17-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-17-test.parquet
#
# Processing day: session_start_date=2019-10-18
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-18/part-00056-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-18-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-18-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-18-test.parquet
#
# Processing day: session_start_date=2019-10-19
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-19/part-00088-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-19-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-19-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-19-test.parquet
#
# Processing day: session_start_date=2019-10-20
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-20/part-00077-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-20-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-20-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-20-test.parquet
#
# Processing day: session_start_date=2019-10-21
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-21/part-00127-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-21-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-21-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-21-test.parquet
#
# Processing day: session_start_date=2019-10-22
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-22/part-00184-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-22-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-22-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-22-test.parquet
#
# Processing day: session_start_date=2019-10-23
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-23/part-00081-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-23-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-23-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-23-test.parquet
#
# Processing day: session_start_date=2019-10-24
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-24/part-00148-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-24-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-24-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-24-test.parquet
#
# Processing day: session_start_date=2019-10-25
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-25/part-00151-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-25-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-25-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-25-test.parquet
#
# Processing day: session_start_date=2019-10-26
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-26/part-00181-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-26-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-26-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-26-test.parquet
#
# Processing day: session_start_date=2019-10-27
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-27/part-00076-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-27-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-27-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-27-test.parquet
#
# Processing day: session_start_date=2019-10-28
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-28/part-00190-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-28-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-28-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-28-test.parquet
#
# Processing day: session_start_date=2019-10-29
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-29/part-00115-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-29-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-29-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-29-test.parquet
#
# Processing day: session_start_date=2019-10-30
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-30/part-00010-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-30-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-30-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-30-test.parquet
#
# Processing day: session_start_date=2019-10-31
# Reading original file: /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-31/part-00056-bca5d158-0ed7-49a5-8413-2de6d87aff02.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-31-train.parquet
# Saving valid set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-31-valid.parquet
# Saving test set to /mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-31-test.parquet

# %% [markdown]
# # Checking Lengths

# %%
import pandas as pd

# %%
df = pd.read_parquet('/mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-18-train.parquet')

# %%
len(df)
# Out:
# 116441

# %%
df.columns
# Out:
# Index(['user_idx', 'user_session', 'session_start_ts', 'sess_seq_len',
#        'bef_sess_seq_length', 'sess_pid_seq', 'sess_etime_seq',
#        'sess_etype_seq', 'sess_csid_seq', 'sess_ccid_seq', 'sess_bid_seq',
#        'sess_price_log_norm_seq', 'sess_dtime_secs_seq',
#        'sess_dtime_secs_log_norm_seq', 'sess_prod_recency_days_seq',
#        'sess_prod_recency_days_log_norm_seq',
#        'sess_relative_price_to_avg_category_seq', 'sess_et_hour_sin_seq',
#        'sess_et_hour_cos_seq', 'sess_et_month_sin_seq',
#        'sess_et_month_cos_seq', 'sess_et_dayofweek_sin_seq',
#        'sess_et_dayofweek_cos_seq', 'sess_et_dayofmonth_sin_seq',
#        'sess_et_dayofmonth_cos_seq', 'sess_session_reversed_order_seq',
#        'bef_sess_pid_seq', 'bef_sess_etime_seq', 'bef_sess_etype_seq',
#        'bef_sess_csid_seq', 'bef_sess_ccid_seq', 'bef_sess_bid_seq',
#        'bef_sess_price_log_seq', 'bef_sess_dtime_secs_seq',
#        'bef_sess_dtime_secs_log_norm_seq', 'bef_sess_prod_recency_days_seq',
#        'bef_sess_prod_recency_days_log_norm_seq',
#        'bef_sess_relative_price_to_avg_category_seq',
#        'bef_sess_et_hour_sin_seq', 'bef_sess_et_hour_cos_seq',
#        'bef_sess_et_month_sin_seq', 'bef_sess_et_month_cos_seq',
#        'bef_sess_et_dayofweek_sin_seq', 'bef_sess_et_dayofweek_cos_seq',
#        'bef_sess_et_dayofmonth_sin_seq', 'bef_sess_et_dayofmonth_cos_seq',
#        'bef_sess_session_reversed_order_seq'],
#       dtype='object')

# %%
df['bef_sess_pid_seq'].apply(len).describe()
# Out:
# count    116441.000000
# mean          9.579426
# std           8.413303
# min           0.000000
# 25%           1.000000
# 50%           8.000000
# 75%          20.000000
# max          20.000000
# Name: bef_sess_pid_seq, dtype: float64
