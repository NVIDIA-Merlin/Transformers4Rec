# %%
import pandas as pd
import os
import gc

# %%
INPUT_PATH = '/mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc.parquet'
OUTPUT_PATH = '/mount/results/repeated_interactions=False/total_months=1/ecommerce_preproc-split'
# !mkdir -p $OUTPUT_PATH

# %%
def fix_event_timestamp(event_ts_sequence):
    MAXIMUM_SESSION_DURATION_SECS = 60 * 120
    DEFAULT_ELAPSED_SECS_BETWEEN_INTERACTIONS = 60
    min_event_ts = min([e for e in event_ts_sequence if e != 0])
    max_event_ts = max(event_ts_sequence)

    if max_event_ts <= min_event_ts + MAXIMUM_SESSION_DURATION_SECS:
        return event_ts_sequence

    else:
        last_ts = None

        result = []
        for etime in event_ts_sequence:
            if etime > min_event_ts + MAXIMUM_SESSION_DURATION_SECS:
                etime = last_ts + DEFAULT_ELAPSED_SECS_BETWEEN_INTERACTIONS
            last_ts = etime
            result.append(etime)

        return result

# %%
def split_train_eval_parquet_file(sessions_df, parquet_path, perc_valid_set):
    #sessions_df = pd.read_parquet(parquet_path)

    # Shuffling the order of sesions
    sessions_df = sessions_df.sample(frac=1).reset_index(drop=True)

    dataset_size = len(sessions_df)

    train_set_limit = dataset_size - int(dataset_size * perc_valid_set)

    train_df = sessions_df[:train_set_limit]
    valid_df = sessions_df[train_set_limit:dataset_size]

    try:

        # Sorting the sessions by start time
        train_df.sort_values("session_start_ts", inplace=True)
        valid_df.sort_values("session_start_ts", inplace=True)

        output_train_path = parquet_path.replace(".parquet", "-train.parquet")
        output_test_path = parquet_path.replace(".parquet", "-test.parquet")

        print('Saving train set to {}'.format(output_train_path))
        print('Saving test set to {}'.format(output_train_path))
        train_df.to_parquet(output_train_path)
        valid_df.to_parquet(output_test_path)

    finally:
        del sessions_df
        del train_df
        del valid_df
        gc.collect()

# %%
for sessions_day_dir in sorted(os.listdir(INPUT_PATH)):
    if os.path.isdir(os.path.join(INPUT_PATH,sessions_day_dir)):
        print('Processing day: {}'.format(sessions_day_dir))
        
        dir_files = os.listdir(os.path.join(INPUT_PATH,sessions_day_dir))
        #Ignoring .crc hidden file
        parquet_name = list([f for f in dir_files if not f.startswith('.')])[0]
        parquet_name_full_path = os.path.join(INPUT_PATH, sessions_day_dir, parquet_name)
        print('Reading original file: '+parquet_name_full_path)
        pd_full = pd.read_parquet(parquet_name_full_path)
                
        # Temporary, as the event timestamps from some rare items of the pre-processed dataset are many days after the session start
        #But, fixing timestamp at this point really is not considered for training
        #pd_full["sess_etime_seq"] = pd_full["sess_etime_seq"].apply(fix_event_timestamp)
        
        print('Saving original file...')
        output_parquet_file = os.path.join(OUTPUT_PATH, sessions_day_dir+'.parquet')
        pd_full.to_parquet(output_parquet_file)
        
        print('Spliting train and test files...')
        split_train_eval_parquet_file(pd_full, output_parquet_file, perc_valid_set=0.1)  
        
        print('')
# Out:
# Processing day: session_start_date=2019-10-01
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-01/part-00066-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-01-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-01-train.parquet
#
# Processing day: session_start_date=2019-10-02
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-02/part-00149-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-02-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-02-train.parquet
#
# Processing day: session_start_date=2019-10-03
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-03/part-00026-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-03-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-03-train.parquet
#
# Processing day: session_start_date=2019-10-04
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-04/part-00045-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-04-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-04-train.parquet
#
# Processing day: session_start_date=2019-10-05
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-05/part-00040-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-05-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-05-train.parquet
#
# Processing day: session_start_date=2019-10-06
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-06/part-00017-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-06-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-06-train.parquet
#
# Processing day: session_start_date=2019-10-07
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-07/part-00191-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-07-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-07-train.parquet
#
# Processing day: session_start_date=2019-10-08
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-08/part-00092-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-08-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-08-train.parquet
#
# Processing day: session_start_date=2019-10-09
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-09/part-00052-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-09-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-09-train.parquet
#
# Processing day: session_start_date=2019-10-10
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-10/part-00043-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-10-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-10-train.parquet
#
# Processing day: session_start_date=2019-10-11
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-11/part-00078-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-11-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-11-train.parquet
#
# Processing day: session_start_date=2019-10-12
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-12/part-00033-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-12-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-12-train.parquet
#
# Processing day: session_start_date=2019-10-13
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-13/part-00153-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-13-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-13-train.parquet
#
# Processing day: session_start_date=2019-10-14
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-14/part-00049-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-14-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-14-train.parquet
#
# Processing day: session_start_date=2019-10-15
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-15/part-00173-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-15-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-15-train.parquet
#
# Processing day: session_start_date=2019-10-16
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-16/part-00095-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-16-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-16-train.parquet
#
# Processing day: session_start_date=2019-10-17
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-17/part-00102-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-17-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-17-train.parquet
#
# Processing day: session_start_date=2019-10-18
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-18/part-00056-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-18-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-18-train.parquet
#
# Processing day: session_start_date=2019-10-19
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-19/part-00088-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-19-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-19-train.parquet
#
# Processing day: session_start_date=2019-10-20
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-20/part-00077-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-20-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-20-train.parquet
#
# Processing day: session_start_date=2019-10-21
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-21/part-00127-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-21-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-21-train.parquet
#
# Processing day: session_start_date=2019-10-22
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-22/part-00184-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-22-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-22-train.parquet
#
# Processing day: session_start_date=2019-10-23
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-23/part-00081-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-23-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-23-train.parquet
#
# Processing day: session_start_date=2019-10-24
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-24/part-00148-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-24-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-24-train.parquet
#
# Processing day: session_start_date=2019-10-25
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-25/part-00151-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-25-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-25-train.parquet
#
# Processing day: session_start_date=2019-10-26
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-26/part-00181-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-26-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-26-train.parquet
#
# Processing day: session_start_date=2019-10-27
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-27/part-00076-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-27-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-27-train.parquet
#
# Processing day: session_start_date=2019-10-28
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-28/part-00190-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-28-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-28-train.parquet
#
# Processing day: session_start_date=2019-10-29
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-29/part-00115-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-29-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-29-train.parquet
#
# Processing day: session_start_date=2019-10-30
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-30/part-00010-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-30-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-30-train.parquet
#
# Processing day: session_start_date=2019-10-31
# Reading original file: /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc.parquet/session_start_date=2019-10-31/part-00056-8cd67fef-333a-4722-8ee7-db42fc2853de.c000.snappy.parquet
# Saving original file...
# Spliting train and test files...
# Saving train set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-31-train.parquet
# Saving test set to /mount/results/repeated_interactions=True/total_months=1/ecommerce_preproc-split/session_start_date=2019-10-31-train.parquet
